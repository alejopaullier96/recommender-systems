# %% [markdown]
# <img src="https://www3.um.edu.uy/logoum.jpg" width=300>
# <h1 align="center">Thesis - HPF nDCG</h1>
# <h2 align="center">Alejo Paullier</h2>

# %% [markdown]
# https://lkpy.lenskit.org/en/stable/knn.html

# %%
from lenskit import batch, topn, util
from lenskit import crossfold as xf
from lenskit.algorithms import Recommender
from lenskit.algorithms.hpf import HPF as hpfl
from hpfrec import HPF
import pandas as pd
import numpy as np
from hyperopt import fmin, tpe, hp, STATUS_OK

ratings = pd.read_csv('D:\\Escritorio\\UM\\Tesis\\ML 1M\\ratings.dat', sep='::',engine='python',
                      names=['user', 'item', 'rating', 'timestamp'])


def eval(aname, algo, train, test):
    fittable = util.clone(algo) # Object cloning means to create an exact copy of the original object.
    fittable = Recommender.adapt(fittable) 
    fittable.fit(train) # Entrenamos el algoritmo con el training dataset
    users = test.user.unique() # Devuelve un array con los users unicos en el testing dataset
    # now we run the recommender
    recs = batch.recommend(fittable, users, 100)
    # add the algorithm name for analyzability
    recs['Algorithm'] = aname
    return recs

# %%
def model_trainer(features):
    all_recs = []
    test_data = []
    features=int(features)
    
    hpf = hpfl(features,maxiter=1) # define algorithm
    
    for train, test in xf.partition_users(ratings[['user', 'item', 'rating']], 5, xf.SampleFrac(0.2)):
        test_data.append(test) # save testing data
        all_recs.append(eval('HPF', hpf, train, test))
    all_recs = pd.concat(all_recs, ignore_index=True)
    test_data = pd.concat(test_data, ignore_index=True)
    rla = topn.RecListAnalysis()
    rla.add_metric(topn.ndcg)
    results = rla.compute(all_recs, test_data)
    return results["ndcg"].mean()

# %%
ndcg = model_trainer(200)
# Out:
# **********************************
# Hierarchical Poisson Factorization
# **********************************
#
# Number of users: 6040
# Number of items: 3701
# Latent factors to use: 200
#
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4455094 | train rmse: 2.8322
# Iteration 20 | train llk: -3602046 | train rmse: 2.6264
# Iteration 30 | train llk: -3289333 | train rmse: 2.5446
# Iteration 40 | train llk: -3131203 | train rmse: 2.5020
# Iteration 50 | train llk: -3038441 | train rmse: 2.4762
# Iteration 60 | train llk: -2977287 | train rmse: 2.4590
# Iteration 70 | train llk: -2933962 | train rmse: 2.4468
# Iteration 80 | train llk: -2902689 | train rmse: 2.4379
# Iteration 90 | train llk: -2877892 | train rmse: 2.4307
# Iteration 100 | train llk: -2857787 | train rmse: 2.4250
#
#
# Optimization finished
# Final log-likelihood: -2857787
# Final RMSE: 2.4250
# Minutes taken (optimization part): 6.2
#
# **********************************
# Hierarchical Poisson Factorization
# **********************************
#
# Number of users: 6040
# Number of items: 3700
# Latent factors to use: 200
#
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4434357 | train rmse: 2.8308
# Iteration 20 | train llk: -3555798 | train rmse: 2.6183
# Iteration 30 | train llk: -3255556 | train rmse: 2.5377
# Iteration 40 | train llk: -3108913 | train rmse: 2.4971
# Iteration 50 | train llk: -3026069 | train rmse: 2.4739
# Iteration 60 | train llk: -2972628 | train rmse: 2.4590
# Iteration 70 | train llk: -2935002 | train rmse: 2.4484
# Iteration 80 | train llk: -2906692 | train rmse: 2.4401
# Iteration 90 | train llk: -2884981 | train rmse: 2.4337
# Iteration 100 | train llk: -2866677 | train rmse: 2.4282
#
#
# Optimization finished
# Final log-likelihood: -2866677
# Final RMSE: 2.4282
# Minutes taken (optimization part): 6.2
#
# **********************************
# Hierarchical Poisson Factorization
# **********************************
#
# Number of users: 6040
# Number of items: 3701
# Latent factors to use: 200
#
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4449351 | train rmse: 2.8294
# Iteration 20 | train llk: -3581685 | train rmse: 2.6213
# Iteration 30 | train llk: -3266164 | train rmse: 2.5396
# Iteration 40 | train llk: -3116299 | train rmse: 2.4988
# Iteration 50 | train llk: -3029258 | train rmse: 2.4746
# Iteration 60 | train llk: -2970771 | train rmse: 2.4585
# Iteration 70 | train llk: -2927697 | train rmse: 2.4463
# Iteration 80 | train llk: -2895586 | train rmse: 2.4372
# Iteration 90 | train llk: -2870873 | train rmse: 2.4301
# Iteration 100 | train llk: -2850828 | train rmse: 2.4241
#
#
# Optimization finished
# Final log-likelihood: -2850828
# Final RMSE: 2.4241
# Minutes taken (optimization part): 6.1
#
# **********************************
# Hierarchical Poisson Factorization
# **********************************
#
# Number of users: 6040
# Number of items: 3702
# Latent factors to use: 200
#
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4419827 | train rmse: 2.8292
# Iteration 20 | train llk: -3549110 | train rmse: 2.6171
# Iteration 30 | train llk: -3251506 | train rmse: 2.5370
# Iteration 40 | train llk: -3109220 | train rmse: 2.4980
# Iteration 50 | train llk: -3028650 | train rmse: 2.4761
# Iteration 60 | train llk: -2975366 | train rmse: 2.4614
# Iteration 70 | train llk: -2937631 | train rmse: 2.4506
# Iteration 80 | train llk: -2910062 | train rmse: 2.4426
# Iteration 90 | train llk: -2889036 | train rmse: 2.4364
# Iteration 100 | train llk: -2872163 | train rmse: 2.4314
#
#
# Optimization finished
# Final log-likelihood: -2872163
# Final RMSE: 2.4314
# Minutes taken (optimization part): 6.1
#
# **********************************
# Hierarchical Poisson Factorization
# **********************************
#
# Number of users: 6040
# Number of items: 3702
# Latent factors to use: 200
#
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4444064 | train rmse: 2.8309
# Iteration 20 | train llk: -3578426 | train rmse: 2.6224
# Iteration 30 | train llk: -3265511 | train rmse: 2.5399
# Iteration 40 | train llk: -3113766 | train rmse: 2.4987
# Iteration 50 | train llk: -3029411 | train rmse: 2.4754
# Iteration 60 | train llk: -2976633 | train rmse: 2.4609
# Iteration 70 | train llk: -2939215 | train rmse: 2.4508
# Iteration 80 | train llk: -2910828 | train rmse: 2.4431
# Iteration 90 | train llk: -2887937 | train rmse: 2.4367
# Iteration 100 | train llk: -2869070 | train rmse: 2.4309
#
#
# Optimization finished
# Final log-likelihood: -2869070
# Final RMSE: 2.4309
# Minutes taken (optimization part): 6.1

# %%
ndcg
# Out:
# 0.400328483416926

# %%
array = []
def objective(params):
    features = params['features']
    metric = model_trainer(features)
    array.append([features,metric])
    return {'loss': metric, 'status': STATUS_OK}

space={'features': hp.uniform('features', 1, 100)}

best = fmin(objective, space, algo=tpe.suggest,max_evals=100)
# Out:
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3702
# Latent factors to use: 40
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4999504 | train rmse: 2.9371
# Iteration 20 | train llk: -4081057 | train rmse: 2.7331
# Iteration 30 | train llk: -3729137 | train rmse: 2.6480
# Iteration 40 | train llk: -3583731 | train rmse: 2.6112
# Iteration 50 | train llk: -3513746 | train rmse: 2.5928
# Iteration 60 | train llk: -3471432 | train rmse: 2.5817
# Iteration 70 | train llk: -3439456 | train rmse: 2.5743
# Iteration 80 | train llk: -3415350 | train rmse: 2.5688
# Iteration 90 | train llk: -3398672 | train rmse: 2.5647
# Iteration 100 | train llk: -3386250 | train rmse: 2.5617
#
#
# Optimization finished
# Final log-likelihood: -3386250
# Final RMSE: 2.5617
# Minutes taken (optimization part): 3.4
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3700
# Latent factors to use: 40
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4912639 | train rmse: 2.9242
# Iteration 20 | train llk: -4045494 | train rmse: 2.7318
# Iteration 30 | train llk: -3750185 | train rmse: 2.6597
# Iteration 40 | train llk: -3609300 | train rmse: 2.6247
# Iteration 50 | train llk: -3516055 | train rmse: 2.6021
# Iteration 60 | train llk: -3455258 | train rmse: 2.5874
# Iteration 70 | train llk: -3420632 | train rmse: 2.5791
# Iteration 80 | train llk: -3398958 | train rmse: 2.5738
# Iteration 90 | train llk: -3382927 | train rmse: 2.5696
# Iteration 100 | train llk: -3371137 | train rmse: 2.5667
#
#
# Optimization finished
# Final log-likelihood: -3371137
# Final RMSE: 2.5667
# Minutes taken (optimization part): 3.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3694
# Latent factors to use: 40
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4948643 | train rmse: 2.9257
# Iteration 20 | train llk: -4062103 | train rmse: 2.7279
# Iteration 30 | train llk: -3724640 | train rmse: 2.6475
# Iteration 40 | train llk: -3571713 | train rmse: 2.6099
# Iteration 50 | train llk: -3493483 | train rmse: 2.5911
# Iteration 60 | train llk: -3441721 | train rmse: 2.5789
# Iteration 70 | train llk: -3403856 | train rmse: 2.5703
# Iteration 80 | train llk: -3377303 | train rmse: 2.5644
# Iteration 90 | train llk: -3359923 | train rmse: 2.5605
# Iteration 100 | train llk: -3347824 | train rmse: 2.5578
#
#
# Optimization finished
# Final log-likelihood: -3347824
# Final RMSE: 2.5578
# Minutes taken (optimization part): 3.4
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3701
# Latent factors to use: 40
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4920737 | train rmse: 2.9151
# Iteration 20 | train llk: -4103399 | train rmse: 2.7373
# Iteration 30 | train llk: -3775330 | train rmse: 2.6585
# Iteration 40 | train llk: -3611129 | train rmse: 2.6196
# Iteration 50 | train llk: -3521891 | train rmse: 2.5993
# Iteration 60 | train llk: -3470911 | train rmse: 2.5879
# Iteration 70 | train llk: -3435838 | train rmse: 2.5800
# Iteration 80 | train llk: -3411039 | train rmse: 2.5742
# Iteration 90 | train llk: -3393255 | train rmse: 2.5702
# Iteration 100 | train llk: -3380089 | train rmse: 2.5671
#
#
# Optimization finished
# Final log-likelihood: -3380089
# Final RMSE: 2.5671
# Minutes taken (optimization part): 3.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3705
# Latent factors to use: 40
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4914817 | train rmse: 2.9239
# Iteration 20 | train llk: -4069977 | train rmse: 2.7343
# Iteration 30 | train llk: -3747675 | train rmse: 2.6535
# Iteration 40 | train llk: -3591182 | train rmse: 2.6145
# Iteration 50 | train llk: -3508703 | train rmse: 2.5943
# Iteration 60 | train llk: -3461896 | train rmse: 2.5833
# Iteration 70 | train llk: -3433660 | train rmse: 2.5768
# Iteration 80 | train llk: -3413553 | train rmse: 2.5720
# Iteration 90 | train llk: -3399035 | train rmse: 2.5686
# Iteration 100 | train llk: -3387778 | train rmse: 2.5659
#
#
# Optimization finished
# Final log-likelihood: -3387778
# Final RMSE: 2.5659
# Minutes taken (optimization part): 3.4
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3699
# Latent factors to use: 72
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4790643 | train rmse: 2.8949
# Iteration 20 | train llk: -3900259 | train rmse: 2.6910
# Iteration 30 | train llk: -3562822 | train rmse: 2.6106
# Iteration 40 | train llk: -3414677 | train rmse: 2.5720
# Iteration 50 | train llk: -3328869 | train rmse: 2.5486
# Iteration 60 | train llk: -3271449 | train rmse: 2.5335
# Iteration 70 | train llk: -3230959 | train rmse: 2.5230
# Iteration 80 | train llk: -3202418 | train rmse: 2.5158
# Iteration 90 | train llk: -3180404 | train rmse: 2.5102
# Iteration 100 | train llk: -3161714 | train rmse: 2.5055
#
#
# Optimization finished
# Final log-likelihood: -3161714
# Final RMSE: 2.5055
# Minutes taken (optimization part): 5.8
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3698
# Latent factors to use: 72
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4790421 | train rmse: 2.8991
# Iteration 20 | train llk: -3876448 | train rmse: 2.6899
# Iteration 30 | train llk: -3537499 | train rmse: 2.6065
# Iteration 40 | train llk: -3382830 | train rmse: 2.5663
# Iteration 50 | train llk: -3294063 | train rmse: 2.5436
# Iteration 60 | train llk: -3238946 | train rmse: 2.5292
# Iteration 70 | train llk: -3202994 | train rmse: 2.5199
# Iteration 80 | train llk: -3178155 | train rmse: 2.5137
# Iteration 90 | train llk: -3159767 | train rmse: 2.5090
# Iteration 100 | train llk: -3145109 | train rmse: 2.5051
#
#
# Optimization finished
# Final log-likelihood: -3145109
# Final RMSE: 2.5051
# Minutes taken (optimization part): 5.5
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3705
# Latent factors to use: 72
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4818499 | train rmse: 2.9022
# Iteration 20 | train llk: -3901388 | train rmse: 2.6938
# Iteration 30 | train llk: -3558413 | train rmse: 2.6086
# Iteration 40 | train llk: -3398852 | train rmse: 2.5677
# Iteration 50 | train llk: -3312507 | train rmse: 2.5452
# Iteration 60 | train llk: -3258967 | train rmse: 2.5313
# Iteration 70 | train llk: -3223820 | train rmse: 2.5222
# Iteration 80 | train llk: -3199562 | train rmse: 2.5160
# Iteration 90 | train llk: -3181372 | train rmse: 2.5114
# Iteration 100 | train llk: -3167687 | train rmse: 2.5079
#
#
# Optimization finished
# Final log-likelihood: -3167687
# Final RMSE: 2.5079
# Minutes taken (optimization part): 5.6
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3706
# Latent factors to use: 72
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4757457 | train rmse: 2.8911
# Iteration 20 | train llk: -3876698 | train rmse: 2.6893
# Iteration 30 | train llk: -3551808 | train rmse: 2.6090
# Iteration 40 | train llk: -3403644 | train rmse: 2.5709
# Iteration 50 | train llk: -3317656 | train rmse: 2.5486
# Iteration 60 | train llk: -3263199 | train rmse: 2.5344
# Iteration 70 | train llk: -3225221 | train rmse: 2.5244
# Iteration 80 | train llk: -3194498 | train rmse: 2.5164
# Iteration 90 | train llk: -3169871 | train rmse: 2.5101
# Iteration 100 | train llk: -3151255 | train rmse: 2.5053
#
#
# Optimization finished
# Final log-likelihood: -3151255
# Final RMSE: 2.5053
# Minutes taken (optimization part): 5.5
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3704
# Latent factors to use: 72
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4747302 | train rmse: 2.8797
# Iteration 20 | train llk: -3866092 | train rmse: 2.6793
# Iteration 30 | train llk: -3534876 | train rmse: 2.6008
# Iteration 40 | train llk: -3381798 | train rmse: 2.5621
# Iteration 50 | train llk: -3298863 | train rmse: 2.5407
# Iteration 60 | train llk: -3246363 | train rmse: 2.5272
# Iteration 70 | train llk: -3211626 | train rmse: 2.5186
# Iteration 80 | train llk: -3186887 | train rmse: 2.5124
# Iteration 90 | train llk: -3167944 | train rmse: 2.5077
# Iteration 100 | train llk: -3151569 | train rmse: 2.5037
#
#
# Optimization finished
# Final log-likelihood: -3151569
# Final RMSE: 2.5037
# Minutes taken (optimization part): 5.5
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3702
# Latent factors to use: 15
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -5184203 | train rmse: 2.9656
# Iteration 20 | train llk: -4517426 | train rmse: 2.8260
# Iteration 30 | train llk: -4235215 | train rmse: 2.7608
# Iteration 40 | train llk: -4068178 | train rmse: 2.7212
# Iteration 50 | train llk: -3974288 | train rmse: 2.7001
# Iteration 60 | train llk: -3925430 | train rmse: 2.6901
# Iteration 70 | train llk: -3900132 | train rmse: 2.6856
# Iteration 80 | train llk: -3885944 | train rmse: 2.6834
# Iteration 90 | train llk: -3876764 | train rmse: 2.6818
# Iteration 100 | train llk: -3869698 | train rmse: 2.6807
#
#
# Optimization finished
# Final log-likelihood: -3869698
# Final RMSE: 2.6807
# Minutes taken (optimization part): 1.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3700
# Latent factors to use: 15
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -5173250 | train rmse: 2.9613
# Iteration 20 | train llk: -4460833 | train rmse: 2.8145
# Iteration 30 | train llk: -4150890 | train rmse: 2.7496
# Iteration 40 | train llk: -4010959 | train rmse: 2.7200
# Iteration 50 | train llk: -3943531 | train rmse: 2.7057
# Iteration 60 | train llk: -3898981 | train rmse: 2.6961
# Iteration 70 | train llk: -3870128 | train rmse: 2.6901
# Iteration 80 | train llk: -3852866 | train rmse: 2.6861
# Iteration 90 | train llk: -3841828 | train rmse: 2.6831
# Iteration 100 | train llk: -3834405 | train rmse: 2.6809
#
#
# Optimization finished
# Final log-likelihood: -3834405
# Final RMSE: 2.6809
# Minutes taken (optimization part): 1.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3703
# Latent factors to use: 15
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -5237389 | train rmse: 2.9740
# Iteration 20 | train llk: -4503981 | train rmse: 2.8291
# Iteration 30 | train llk: -4189777 | train rmse: 2.7648
# Iteration 40 | train llk: -4026171 | train rmse: 2.7281
# Iteration 50 | train llk: -3948665 | train rmse: 2.7109
# Iteration 60 | train llk: -3908736 | train rmse: 2.7017
# Iteration 70 | train llk: -3885947 | train rmse: 2.6968
# Iteration 80 | train llk: -3868022 | train rmse: 2.6930
# Iteration 90 | train llk: -3851835 | train rmse: 2.6898
# Iteration 100 | train llk: -3837374 | train rmse: 2.6871
#
#
# Optimization finished
# Final log-likelihood: -3837374
# Final RMSE: 2.6871
# Minutes taken (optimization part): 1.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3705
# Latent factors to use: 15
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -5212436 | train rmse: 2.9720
# Iteration 20 | train llk: -4457956 | train rmse: 2.8171
# Iteration 30 | train llk: -4185720 | train rmse: 2.7544
# Iteration 40 | train llk: -4057304 | train rmse: 2.7235
# Iteration 50 | train llk: -3981467 | train rmse: 2.7045
# Iteration 60 | train llk: -3929577 | train rmse: 2.6912
# Iteration 70 | train llk: -3893164 | train rmse: 2.6831
# Iteration 80 | train llk: -3869695 | train rmse: 2.6784
# Iteration 90 | train llk: -3853651 | train rmse: 2.6748
# Iteration 100 | train llk: -3842782 | train rmse: 2.6728
#
#
# Optimization finished
# Final log-likelihood: -3842782
# Final RMSE: 2.6728
# Minutes taken (optimization part): 1.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3703
# Latent factors to use: 15
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -5189918 | train rmse: 2.9653
# Iteration 20 | train llk: -4500994 | train rmse: 2.8246
# Iteration 30 | train llk: -4228574 | train rmse: 2.7640
# Iteration 40 | train llk: -4071819 | train rmse: 2.7282
# Iteration 50 | train llk: -3991003 | train rmse: 2.7092
# Iteration 60 | train llk: -3949156 | train rmse: 2.6999
# Iteration 70 | train llk: -3923632 | train rmse: 2.6940
# Iteration 80 | train llk: -3906290 | train rmse: 2.6902
# Iteration 90 | train llk: -3895270 | train rmse: 2.6877
# Iteration 100 | train llk: -3887355 | train rmse: 2.6859
#
#
# Optimization finished
# Final log-likelihood: -3887355
# Final RMSE: 2.6859
# Minutes taken (optimization part): 1.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3700
# Latent factors to use: 49
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4907529 | train rmse: 2.9223
# Iteration 20 | train llk: -4074340 | train rmse: 2.7302
# Iteration 30 | train llk: -3725655 | train rmse: 2.6459
# Iteration 40 | train llk: -3559268 | train rmse: 2.6057
# Iteration 50 | train llk: -3463501 | train rmse: 2.5822
# Iteration 60 | train llk: -3403656 | train rmse: 2.5679
# Iteration 70 | train llk: -3362392 | train rmse: 2.5584
# Iteration 80 | train llk: -3332311 | train rmse: 2.5515
# Iteration 90 | train llk: -3309415 | train rmse: 2.5464
# Iteration 100 | train llk: -3291082 | train rmse: 2.5424
#
#
# Optimization finished
# Final log-likelihood: -3291082
# Final RMSE: 2.5424
# Minutes taken (optimization part): 3.9
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3700
# Latent factors to use: 49
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4836086 | train rmse: 2.9134
# Iteration 20 | train llk: -3990967 | train rmse: 2.7166
# Iteration 30 | train llk: -3669653 | train rmse: 2.6360
# Iteration 40 | train llk: -3511198 | train rmse: 2.5959
# Iteration 50 | train llk: -3418610 | train rmse: 2.5726
# Iteration 60 | train llk: -3360865 | train rmse: 2.5586
# Iteration 70 | train llk: -3324814 | train rmse: 2.5503
# Iteration 80 | train llk: -3300966 | train rmse: 2.5447
# Iteration 90 | train llk: -3283832 | train rmse: 2.5406
# Iteration 100 | train llk: -3270650 | train rmse: 2.5376
#
#
# Optimization finished
# Final log-likelihood: -3270650
# Final RMSE: 2.5376
# Minutes taken (optimization part): 3.8
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3699
# Latent factors to use: 49
# ...
# Iteration 60 | train llk: -3333830 | train rmse: 2.5543
# Iteration 70 | train llk: -3296121 | train rmse: 2.5444
# Iteration 80 | train llk: -3268819 | train rmse: 2.5374
# Iteration 90 | train llk: -3249491 | train rmse: 2.5324
# Iteration 100 | train llk: -3235333 | train rmse: 2.5287
#
#
# Optimization finished
# Final log-likelihood: -3235333
# Final RMSE: 2.5287
# Minutes taken (optimization part): 4.4
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3703
# Latent factors to use: 57
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4871508 | train rmse: 2.9140
# Iteration 20 | train llk: -3984093 | train rmse: 2.7156
# Iteration 30 | train llk: -3645175 | train rmse: 2.6313
# Iteration 40 | train llk: -3481259 | train rmse: 2.5894
# Iteration 50 | train llk: -3389373 | train rmse: 2.5659
# Iteration 60 | train llk: -3337448 | train rmse: 2.5527
# Iteration 70 | train llk: -3302548 | train rmse: 2.5441
# Iteration 80 | train llk: -3277598 | train rmse: 2.5380
# Iteration 90 | train llk: -3259318 | train rmse: 2.5336
# Iteration 100 | train llk: -3245211 | train rmse: 2.5301
#
#
# Optimization finished
# Final log-likelihood: -3245211
# Final RMSE: 2.5301
# Minutes taken (optimization part): 4.6
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3698
# Latent factors to use: 57
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4839002 | train rmse: 2.9022
# Iteration 20 | train llk: -3961048 | train rmse: 2.7087
# Iteration 30 | train llk: -3638082 | train rmse: 2.6295
# Iteration 40 | train llk: -3468820 | train rmse: 2.5871
# Iteration 50 | train llk: -3376737 | train rmse: 2.5637
# Iteration 60 | train llk: -3323327 | train rmse: 2.5502
# Iteration 70 | train llk: -3286633 | train rmse: 2.5408
# Iteration 80 | train llk: -3260391 | train rmse: 2.5341
# Iteration 90 | train llk: -3239822 | train rmse: 2.5289
# Iteration 100 | train llk: -3223509 | train rmse: 2.5250
#
#
# Optimization finished
# Final log-likelihood: -3223509
# Final RMSE: 2.5250
# Minutes taken (optimization part): 4.4
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3705
# Latent factors to use: 57
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4847650 | train rmse: 2.9071
# Iteration 20 | train llk: -3957789 | train rmse: 2.7050
# Iteration 30 | train llk: -3636414 | train rmse: 2.6282
# Iteration 40 | train llk: -3489197 | train rmse: 2.5908
# Iteration 50 | train llk: -3407465 | train rmse: 2.5697
# Iteration 60 | train llk: -3357381 | train rmse: 2.5562
# Iteration 70 | train llk: -3323612 | train rmse: 2.5473
# Iteration 80 | train llk: -3299483 | train rmse: 2.5411
# Iteration 90 | train llk: -3281440 | train rmse: 2.5363
# Iteration 100 | train llk: -3267484 | train rmse: 2.5327
#
#
# Optimization finished
# Final log-likelihood: -3267484
# Final RMSE: 2.5327
# Minutes taken (optimization part): 4.5
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3704
# Latent factors to use: 81
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4720421 | train rmse: 2.8875
# Iteration 20 | train llk: -3847860 | train rmse: 2.6826
# Iteration 30 | train llk: -3510104 | train rmse: 2.5961
#   5%|██▏                                        | 5/100 [1:45:33<32:52:03, 1245.51s/it, best loss: 0.34667699959702164]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-8599e9bb8b9b> in <module>
#       8 space={'features': hp.uniform('features', 1, 100)}
#       9
# ---> 10 best = fmin(objective, space, algo=tpe.suggest,max_evals=100)
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     405                     show_progressbar=show_progressbar)
#     406     rval.catch_eval_exceptions = catch_eval_exceptions
# --> 407     rval.exhaust()
#     408     if return_argmin:
#     409         return trials.argmin
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\fmin.py in exhaust(self)
#     260     def exhaust(self):
#     261         n_done = len(self.trials)
# --> 262         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     263         self.trials.refresh()
#     264         return self
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\fmin.py in run(self, N, block_until_done)
#     225                     else:
#     226                         # -- loop over trials and do the jobs directly
# --> 227                         self.serial_evaluate()
#     228
#     229                     try:
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\fmin.py in serial_evaluate(self, N)
#     139                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     140                 try:
# --> 141                     result = self.domain.evaluate(spec, ctrl)
#     142                 except Exception as e:
#     143                     logger.info('job exception: %s' % str(e))
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\base.py in evaluate(self, config, ctrl, attach_attachments)
#     842                 memo=memo,
#     843                 print_node_on_error=self.rec_eval_print_node_on_error)
# --> 844             rval = self.fn(pyll_rval)
#     845
#     846         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-3-8599e9bb8b9b> in objective(params)
#       2 def objective(params):
#       3     features = params['features']
# ----> 4     metric = model_trainer(features)
#       5     array.append([features,metric])
#       6     return {'loss': metric, 'status': STATUS_OK}
#
# <ipython-input-2-c65062ee0877> in model_trainer(features)
#       8     for train, test in xf.partition_users(ratings[['user', 'item', 'rating']], 5, xf.SampleFrac(0.2)):
#       9         test_data.append(test) # save testing data
# ---> 10         all_recs.append(eval('HPF', hpf, train, test))
#      11     all_recs = pd.concat(all_recs, ignore_index=True)
#      12     test_data = pd.concat(test_data, ignore_index=True)
#
# <ipython-input-1-88001a6a8c46> in eval(aname, algo, train, test)
#      15     fittable = util.clone(algo) # Object cloning means to create an exact copy of the original object.
#      16     fittable = Recommender.adapt(fittable)
# ---> 17     fittable.fit(train) # Entrenamos el algoritmo con el training dataset
#      18     users = test.user.unique() # Devuelve un array con los users unicos en el testing dataset
#      19     # now we run the recommender
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\lenskit\algorithms\basic.py in fit(self, ratings, *args, **kwargs)
#     297                 Additional arguments for the predictor to use in its training process.
#     298         """
# --> 299         self.predictor.fit(ratings, *args, **kwargs)
#     300         self.selector.fit(ratings)
#     301         return self
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\lenskit\algorithms\hpf.py in fit(self, ratings)
#      44
#      45         _logger.info('fitting HPF model with %d features', self.features)
# ---> 46         hpf.fit(hpfdf)
#      47
#      48         self.user_index_ = users
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hpfrec\__init__.py in fit(self, counts_df, val_set)
#     399
#     400                 self._cast_before_fit()
# --> 401                 self._fit()
#     402
#     403                 ## after terminating optimization
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hpfrec\__init__.py in _fit(self)
#     634                         self.val_set.Count.values, self.val_set.UserId.values, self.val_set.ItemId.values,
#     635                         cython_loops.cast_int(self.full_llk), cython_loops.cast_int(self.keep_all_objs),
# --> 636                         cython_loops.cast_int(self.alloc_full_phi)
#     637 			)
#     638
#
# hpfrec\cython_loops.pyx in hpfrec.cython_loops.fit_hpf()
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      32     return umr_minimum(a, axis, None, out, keepdims, initial)
#      33
# ---> 34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      35          initial=_NoValue):
#      36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#
# KeyboardInterrupt:

# %%
array # 540.47
# Out:
# [[46.03245754114246, 0.3889689891633376],
#  [10.638205362284651, 0.3242665416003691],
#  [53.99998708290729, 0.39409359092121626],
#  [70.64404308778502, 0.39914125634610154],
#  [42.3220360852923, 0.3894496964624833],
#  [94.24384159908107, 0.4053535614799483],
#  [42.78969149552001, 0.3909731220249033],
#  [99.83634607152612, 0.40506217370524955],
#  [31.55381584070685, 0.3804560076736961],
#  [90.60578932277534, 0.405030784854978],
#  [42.86920781727429, 0.3859073110379881],
#  [22.22881238741727, 0.3651337685574952],
#  [62.168657190044335, 0.40230097600281095],
#  [26.10615448141448, 0.37083620322330774],
#  [86.5450049222734, 0.405335558689985],
#  [50.05890767927245, 0.3948007217359485],
#  [56.89190840916548, 0.39671257520813136],
#  [62.52961373641129, 0.39666424524404764],
#  [19.88444706319474, 0.36129040099809345],
#  [57.34440585148276, 0.39494607090002737]]

# %%
array
# Out:
# [[70.57168517715446, 0.39970063543638185]]

# %%
array
# Out:
# [[64.16889454623012, 0.40128780344780224],
#  [57.9432052583412, 0.3956184796906879],
#  [90.3320192250555, 0.39954674964673814],
#  [69.67268612521052, 0.39875664200217353],
#  [9.027747323342187, 0.31738036613793164],
#  [18.028382891597815, 0.35850937418720363],
#  [69.44005536792127, 0.4018362006229848],
#  [52.87758366108038, 0.39366834428393666],
#  [92.40707064999124, 0.40410231867781055],
#  [11.2591372457911, 0.3311216468950095],
#  [9.089088927352236, 0.32046343521049786],
#  [83.96876967750167, 0.40130709898772415],
#  [10.57577288641147, 0.32561677992444793],
#  [41.58706333840771, 0.38802292895002577],
#  [91.77589020398028, 0.3998755628015072],
#  [38.60523065045376, 0.3854337723387175],
#  [88.55171504482158, 0.4055972132138049],
#  [76.44013700790613, 0.4024538395566857],
#  [64.52718106786169, 0.4011382635537632]]

# %%
array
# Out:
# [[23.199433232913872, 0.3702609732139583],
#  [15.41119422278794, 0.34903069262762987],
#  [29.178634605686625, 0.377643458324074],
#  [6.420676629189062, 0.29871506390069646],
#  [73.97920145819117, 0.40314646494916945],
#  [85.15688726276572, 0.4018351838969853],
#  [30.354561228622963, 0.37842246121516276],
#  [55.10890651657882, 0.39698036785898594],
#  [74.90513076150964, 0.40509088382647185],
#  [55.988963982923195, 0.3959840947095082],
#  [36.706970489650324, 0.3846621587776013],
#  [19.069935290569777, 0.35799848622696545],
#  [24.775618894828735, 0.3668785164473996]]

# %%
array # 516.40
# Out:
# [[19.704117239799643, 0.3610241023377194],
#  [95.07400409290368, 0.40618922533051943],
#  [79.93429019092763, 0.3998328250324392],
#  [95.12138581118117, 0.4023875405806301],
#  [12.152156994183974, 0.33408961558144545],
#  [86.92841182645392, 0.4020676949031186],
#  [64.9713859274742, 0.3980582298509286],
#  [5.448057288109046, 0.2927269228848858],
#  [6.297932428418408, 0.2978160633999604],
#  [19.872161142923648, 0.35939329608730775],
#  [84.02980089766754, 0.39914730786346675],
#  [63.264910313593894, 0.39667997599288746],
#  [99.32608780339072, 0.40622923894312024],
#  [97.0223746900284, 0.40244561174904875],
#  [46.07069484780484, 0.38959197348799035],
#  [47.23320893387159, 0.3907814023935565],
#  [24.11297718195525, 0.36823093680049745],
#  [85.33126620786123, 0.4024274496633911],
#  [50.47595438880378, 0.39435269516553606],
#  [30.301197454466998, 0.3770746869036446]]

# %%
array #539.82s/it
# Out:
# [[94.20872335554782, 0.40047300075806863],
#  [64.7412917514767, 0.3998811259704453],
#  [18.73846229979132, 0.35832816288436237],
#  [91.85737323144325, 0.4070707538150645],
#  [6.390789202244147, 0.2983549774542604]]

# %%
array
# Out:
# [[79.93771987806369, 0.39745310384201926],
#  [53.71705856029021, 0.3942975460086728],
#  [13.689258828003538, 0.3390672561378367],
#  [31.520315811228645, 0.3810059791939544],
#  [67.8470392857221, 0.3967255617627476],
#  [70.84886938087365, 0.4006417644929664],
#  [36.49382150071445, 0.3852237697882613]]

# %%
array
# Out:
# [[40.85690846369436, 0.3860341795998637],
#  [72.01980471903066, 0.39988301624393735],
#  [15.116745037517475, 0.34667699959702164],
#  [49.15257189552348, 0.392178888197196],
#  [57.87045260349703, 0.392673832380934]]

# %%
array
# Out:
# [[9.110543216105077, 0.31580838988481713],
#  [12.648920430733861, 0.33381201363439794],
#  [27.98903560443836, 0.3699384140838549],
#  [42.091341458276936, 0.39117137806575986],
#  [83.79753566175134, 0.3985340997240504],
#  [77.14079726542221, 0.4021184547328285],
#  [16.820031635218605, 0.3538865224271037],
#  [58.84061073500584, 0.39613952985869405],
#  [29.38977030483631, 0.3767522455746386],
#  [94.07226174613172, 0.4035357346774971]]

# %%
metric = pd.DataFrame(array)
metric.columns = ['features','nDCG']
metric.head()
# Out:
#     features      nDCG
# 0   9.110543  0.315808
# 1  12.648920  0.333812
# 2  27.989036  0.369938
# 3  42.091341  0.391171
# 4  83.797536  0.398534

# %%
metric.sort_values(by=['nDCG'],ascending=False).head(10)
# Out:
#      features      nDCG
# 20  91.857373  0.407071
# 34  99.326088  0.406229
# 23  95.074004  0.406189
# 71  88.551715  0.405597
# 80  94.243842  0.405354
# 89  86.545005  0.405336
# 50  74.905131  0.405091
# 82  99.836346  0.405062
# 84  90.605789  0.405031
# 63  92.407071  0.404102

# %%
metric.to_csv('metric_nDCG.csv', index=False)

# %%
array = [[9.110543216105077, 0.31580838988481713],
 [12.648920430733861, 0.33381201363439794],
 [27.98903560443836, 0.3699384140838549],
 [42.091341458276936, 0.39117137806575986],
 [83.79753566175134, 0.3985340997240504],
 [77.14079726542221, 0.4021184547328285],
 [16.820031635218605, 0.3538865224271037],
 [58.84061073500584, 0.39613952985869405],
 [29.38977030483631, 0.3767522455746386],
 [94.07226174613172, 0.4035357346774971],
 [79.93771987806369, 0.39745310384201926],
 [53.71705856029021, 0.3942975460086728],
 [13.689258828003538, 0.3390672561378367],
 [31.520315811228645, 0.3810059791939544],
 [67.8470392857221, 0.3967255617627476],
 [70.84886938087365, 0.4006417644929664],
 [36.49382150071445, 0.3852237697882613],
 [94.20872335554782, 0.40047300075806863],
 [64.7412917514767, 0.3998811259704453],
 [18.73846229979132, 0.35832816288436237],
 [91.85737323144325, 0.4070707538150645],
 [6.390789202244147, 0.2983549774542604],
 [19.704117239799643, 0.3610241023377194],
 [95.07400409290368, 0.40618922533051943],
 [79.93429019092763, 0.3998328250324392],
 [95.12138581118117, 0.4023875405806301],
 [12.152156994183974, 0.33408961558144545],
 [86.92841182645392, 0.4020676949031186],
 [64.9713859274742, 0.3980582298509286],
 [5.448057288109046, 0.2927269228848858],
 [6.297932428418408, 0.2978160633999604],
 [19.872161142923648, 0.35939329608730775],
 [84.02980089766754, 0.39914730786346675],
 [63.264910313593894, 0.39667997599288746],
 [99.32608780339072, 0.40622923894312024],
 [97.0223746900284, 0.40244561174904875],
 [46.07069484780484, 0.38959197348799035],
 [47.23320893387159, 0.3907814023935565],
 [24.11297718195525, 0.36823093680049745],
 [85.33126620786123, 0.4024274496633911],
 [50.47595438880378, 0.39435269516553606],
 [30.301197454466998, 0.3770746869036446],
 [23.199433232913872, 0.3702609732139583],
 [15.41119422278794, 0.34903069262762987],
 [29.178634605686625, 0.377643458324074],
 [6.420676629189062, 0.29871506390069646],
 [73.97920145819117, 0.40314646494916945],
 [85.15688726276572, 0.4018351838969853],
 [30.354561228622963, 0.37842246121516276],
 [55.10890651657882, 0.39698036785898594],
 [74.90513076150964, 0.40509088382647185],
 [55.988963982923195, 0.3959840947095082],
 [36.706970489650324, 0.3846621587776013],
 [19.069935290569777, 0.35799848622696545],
 [24.775618894828735, 0.3668785164473996],
 [64.16889454623012, 0.40128780344780224],
 [57.9432052583412, 0.3956184796906879],
 [90.3320192250555, 0.39954674964673814],
 [69.67268612521052, 0.39875664200217353],
 [9.027747323342187, 0.31738036613793164],
 [18.028382891597815, 0.35850937418720363],
 [69.44005536792127, 0.4018362006229848],
 [52.87758366108038, 0.39366834428393666],
 [92.40707064999124, 0.40410231867781055],
 [11.2591372457911, 0.3311216468950095],
 [9.089088927352236, 0.32046343521049786],
 [83.96876967750167, 0.40130709898772415],
 [10.57577288641147, 0.32561677992444793],
 [41.58706333840771, 0.38802292895002577],
 [91.77589020398028, 0.3998755628015072],
 [38.60523065045376, 0.3854337723387175],
 [88.55171504482158, 0.4055972132138049],
 [76.44013700790613, 0.4024538395566857],
 [64.52718106786169, 0.4011382635537632],
 [70.57168517715446, 0.39970063543638185],
 [46.03245754114246, 0.3889689891633376],
 [10.638205362284651, 0.3242665416003691],
 [53.99998708290729, 0.39409359092121626],
 [70.64404308778502, 0.39914125634610154],
 [42.3220360852923, 0.3894496964624833],
 [94.24384159908107, 0.4053535614799483],
 [42.78969149552001, 0.3909731220249033],
 [99.83634607152612, 0.40506217370524955],
 [31.55381584070685, 0.3804560076736961],
 [90.60578932277534, 0.405030784854978],
 [42.86920781727429, 0.3859073110379881],
 [22.22881238741727, 0.3651337685574952],
 [62.168657190044335, 0.40230097600281095],
 [26.10615448141448, 0.37083620322330774],
 [86.5450049222734, 0.405335558689985],
 [50.05890767927245, 0.3948007217359485],
 [56.89190840916548, 0.39671257520813136],
 [62.52961373641129, 0.39666424524404764],
 [19.88444706319474, 0.36129040099809345],
 [57.34440585148276, 0.39494607090002737],
 [40.85690846369436, 0.3860341795998637],
 [72.01980471903066, 0.39988301624393735],
 [15.116745037517475, 0.34667699959702164],
 [49.15257189552348, 0.392178888197196],
 [57.87045260349703, 0.392673832380934]]
