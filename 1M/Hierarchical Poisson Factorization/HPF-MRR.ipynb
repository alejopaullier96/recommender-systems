# %% [markdown]
# <img src="https://www3.um.edu.uy/logoum.jpg" width=300>
# <h1 align="center">Thesis - HPF MRR</h1>
# <h2 align="center">Alejo Paullier</h2>

# %% [markdown]
# https://lkpy.lenskit.org/en/stable/knn.html

# %%
from lenskit import batch, topn, util
from lenskit import crossfold as xf
from lenskit.algorithms import Recommender
from lenskit.algorithms.hpf import HPF as hpfl
from hpfrec import HPF
import pandas as pd
import numpy as np
from hyperopt import fmin, tpe, hp, STATUS_OK

ratings = pd.read_csv('D:\\Escritorio\\UM\\Tesis\\ML 1M\\ratings.dat', sep='::',engine='python',
                      names=['user', 'item', 'rating', 'timestamp'])


def eval(aname, algo, train, test):
    fittable = util.clone(algo) # Object cloning means to create an exact copy of the original object.
    fittable = Recommender.adapt(fittable) 
    fittable.fit(train) # Entrenamos el algoritmo con el training dataset
    users = test.user.unique() # Devuelve un array con los users unicos en el testing dataset
    # now we run the recommender
    recs = batch.recommend(fittable, users, 100)
    # add the algorithm name for analyzability
    recs['Algorithm'] = aname
    return recs

# %%
def model_trainer(features):
    all_recs = []
    test_data = []
    features=int(features)
    
    hpf = hpfl(features,verbose=False) # define algorithm
    
    for train, test in xf.partition_users(ratings[['user', 'item', 'rating']], 5, xf.SampleFrac(0.2)):
        test_data.append(test) # save testing data
        all_recs.append(eval('HPF', hpf, train, test))
    all_recs = pd.concat(all_recs, ignore_index=True)
    test_data = pd.concat(test_data, ignore_index=True)
    rla = topn.RecListAnalysis()
    rla.add_metric(topn.recip_rank)
    results = rla.compute(all_recs, test_data)
                          
    return results["recip_rank"].mean()

# %%
array = []
def objective(params):
    features = params['features']
    metric = model_trainer(features)
    array.append([features,metric])
    return {'loss': -metric, 'status': STATUS_OK}

space={'features': hp.uniform('features', 1, 100)}

best = fmin(objective, space, algo=tpe.suggest,max_evals=100)
# Out:
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3706
# Latent factors to use: 65
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4831873 | train rmse: 2.9072
# Iteration 20 | train llk: -3927840 | train rmse: 2.7020
# Iteration 30 | train llk: -3592722 | train rmse: 2.6209
# Iteration 40 | train llk: -3428570 | train rmse: 2.5799
# Iteration 50 | train llk: -3341027 | train rmse: 2.5576
# Iteration 60 | train llk: -3285855 | train rmse: 2.5434
# Iteration 70 | train llk: -3249427 | train rmse: 2.5341
# Iteration 80 | train llk: -3220858 | train rmse: 2.5269
# Iteration 90 | train llk: -3198934 | train rmse: 2.5214
# Iteration 100 | train llk: -3181765 | train rmse: 2.5170
#
#
# Optimization finished
# Final log-likelihood: -3181765
# Final RMSE: 2.5170
# Minutes taken (optimization part): 2.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3699
# Latent factors to use: 65
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4803054 | train rmse: 2.8998
# Iteration 20 | train llk: -3932375 | train rmse: 2.6975
# Iteration 30 | train llk: -3606266 | train rmse: 2.6183
# Iteration 40 | train llk: -3452169 | train rmse: 2.5798
# Iteration 50 | train llk: -3366124 | train rmse: 2.5588
# Iteration 60 | train llk: -3310354 | train rmse: 2.5448
# Iteration 70 | train llk: -3269860 | train rmse: 2.5344
# Iteration 80 | train llk: -3237643 | train rmse: 2.5259
# Iteration 90 | train llk: -3210962 | train rmse: 2.5183
# Iteration 100 | train llk: -3190467 | train rmse: 2.5129
#
#
# Optimization finished
# Final log-likelihood: -3190467
# Final RMSE: 2.5129
# Minutes taken (optimization part): 2.0
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3703
# Latent factors to use: 65
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4819813 | train rmse: 2.9090
# Iteration 20 | train llk: -3967999 | train rmse: 2.7129
# Iteration 30 | train llk: -3624146 | train rmse: 2.6281
# Iteration 40 | train llk: -3450772 | train rmse: 2.5849
# Iteration 50 | train llk: -3355151 | train rmse: 2.5605
# Iteration 60 | train llk: -3293649 | train rmse: 2.5447
# Iteration 70 | train llk: -3254090 | train rmse: 2.5347
# Iteration 80 | train llk: -3225837 | train rmse: 2.5276
# Iteration 90 | train llk: -3205022 | train rmse: 2.5222
# Iteration 100 | train llk: -3188915 | train rmse: 2.5180
#
#
# Optimization finished
# Final log-likelihood: -3188915
# Final RMSE: 2.5180
# Minutes taken (optimization part): 2.0
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3703
# Latent factors to use: 65
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4816427 | train rmse: 2.8995
# Iteration 20 | train llk: -3929904 | train rmse: 2.6993
# Iteration 30 | train llk: -3592224 | train rmse: 2.6162
# Iteration 40 | train llk: -3435606 | train rmse: 2.5761
# Iteration 50 | train llk: -3346424 | train rmse: 2.5531
# Iteration 60 | train llk: -3290783 | train rmse: 2.5386
# Iteration 70 | train llk: -3252319 | train rmse: 2.5286
# Iteration 80 | train llk: -3223583 | train rmse: 2.5211
# Iteration 90 | train llk: -3201022 | train rmse: 2.5155
# Iteration 100 | train llk: -3183162 | train rmse: 2.5114
#
#
# Optimization finished
# Final log-likelihood: -3183162
# Final RMSE: 2.5114
# Minutes taken (optimization part): 2.0
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3700
# Latent factors to use: 65
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4797163 | train rmse: 2.9004
# Iteration 20 | train llk: -3938910 | train rmse: 2.7048
# Iteration 30 | train llk: -3594389 | train rmse: 2.6204
# Iteration 40 | train llk: -3430652 | train rmse: 2.5787
# Iteration 50 | train llk: -3341003 | train rmse: 2.5554
# Iteration 60 | train llk: -3285921 | train rmse: 2.5411
# Iteration 70 | train llk: -3249518 | train rmse: 2.5316
# Iteration 80 | train llk: -3223993 | train rmse: 2.5247
# Iteration 90 | train llk: -3204564 | train rmse: 2.5194
# Iteration 100 | train llk: -3188895 | train rmse: 2.5152
#
#
# Optimization finished
# Final log-likelihood: -3188895
# Final RMSE: 2.5152
# Minutes taken (optimization part): 2.0
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3695
# Latent factors to use: 34
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4982436 | train rmse: 2.9353
# Iteration 20 | train llk: -4168390 | train rmse: 2.7497
# Iteration 30 | train llk: -3834517 | train rmse: 2.6708
# Iteration 40 | train llk: -3670851 | train rmse: 2.6324
# Iteration 50 | train llk: -3581979 | train rmse: 2.6112
# Iteration 60 | train llk: -3529070 | train rmse: 2.5985
# Iteration 70 | train llk: -3496324 | train rmse: 2.5906
# Iteration 80 | train llk: -3475072 | train rmse: 2.5854
# Iteration 90 | train llk: -3459468 | train rmse: 2.5816
# Iteration 100 | train llk: -3447563 | train rmse: 2.5788
#
#
# Optimization finished
# Final log-likelihood: -3447563
# Final RMSE: 2.5788
# Minutes taken (optimization part): 1.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3699
# Latent factors to use: 34
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4995289 | train rmse: 2.9349
# Iteration 20 | train llk: -4162335 | train rmse: 2.7497
# Iteration 30 | train llk: -3810447 | train rmse: 2.6685
# Iteration 40 | train llk: -3655319 | train rmse: 2.6301
# Iteration 50 | train llk: -3575796 | train rmse: 2.6103
# Iteration 60 | train llk: -3526907 | train rmse: 2.5982
# Iteration 70 | train llk: -3496835 | train rmse: 2.5910
# Iteration 80 | train llk: -3476276 | train rmse: 2.5861
# Iteration 90 | train llk: -3460397 | train rmse: 2.5822
# Iteration 100 | train llk: -3448118 | train rmse: 2.5792
#
#
# Optimization finished
# Final log-likelihood: -3448118
# Final RMSE: 2.5792
# Minutes taken (optimization part): 1.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3703
# Latent factors to use: 34
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4993370 | train rmse: 2.9340
# Iteration 20 | train llk: -4163689 | train rmse: 2.7504
# Iteration 30 | train llk: -3845244 | train rmse: 2.6734
# Iteration 40 | train llk: -3689073 | train rmse: 2.6343
# Iteration 50 | train llk: -3600107 | train rmse: 2.6128
# Iteration 60 | train llk: -3544295 | train rmse: 2.5987
# Iteration 70 | train llk: -3508612 | train rmse: 2.5902
# Iteration 80 | train llk: -3486327 | train rmse: 2.5850
# Iteration 90 | train llk: -3470244 | train rmse: 2.5815
# Iteration 100 | train llk: -3458647 | train rmse: 2.5790
#
#
# Optimization finished
# Final log-likelihood: -3458647
# Final RMSE: 2.5790
# Minutes taken (optimization part): 1.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3701
# Latent factors to use: 34
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -5028995 | train rmse: 2.9413
# Iteration 20 | train llk: -4207854 | train rmse: 2.7613
# Iteration 30 | train llk: -3854490 | train rmse: 2.6779
# Iteration 40 | train llk: -3681372 | train rmse: 2.6374
# Iteration 50 | train llk: -3591516 | train rmse: 2.6164
# Iteration 60 | train llk: -3542697 | train rmse: 2.6044
# Iteration 70 | train llk: -3513623 | train rmse: 2.5971
# Iteration 80 | train llk: -3492514 | train rmse: 2.5920
# Iteration 90 | train llk: -3475418 | train rmse: 2.5880
# Iteration 100 | train llk: -3461281 | train rmse: 2.5847
#
#
# Optimization finished
# Final log-likelihood: -3461281
# Final RMSE: 2.5847
# Minutes taken (optimization part): 1.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3700
# Latent factors to use: 34
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -5001113 | train rmse: 2.9272
# Iteration 20 | train llk: -4155518 | train rmse: 2.7420
# Iteration 30 | train llk: -3835615 | train rmse: 2.6710
# Iteration 40 | train llk: -3666738 | train rmse: 2.6304
# Iteration 50 | train llk: -3573759 | train rmse: 2.6073
# Iteration 60 | train llk: -3520870 | train rmse: 2.5946
# Iteration 70 | train llk: -3487068 | train rmse: 2.5868
# Iteration 80 | train llk: -3464149 | train rmse: 2.5813
# Iteration 90 | train llk: -3447380 | train rmse: 2.5775
# Iteration 100 | train llk: -3434782 | train rmse: 2.5746
#
#
# Optimization finished
# Final log-likelihood: -3434782
# Final RMSE: 2.5746
# Minutes taken (optimization part): 1.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3702
# Latent factors to use: 60
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4839830 | train rmse: 2.9061
# Iteration 20 | train llk: -3938806 | train rmse: 2.7039
# Iteration 30 | train llk: -3583103 | train rmse: 2.6168
# Iteration 40 | train llk: -3424328 | train rmse: 2.5763
# Iteration 50 | train llk: -3339668 | train rmse: 2.5546
# Iteration 60 | train llk: -3287138 | train rmse: 2.5409
# Iteration 70 | train llk: -3251799 | train rmse: 2.5320
# Iteration 80 | train llk: -3228384 | train rmse: 2.5259
# Iteration 90 | train llk: -3211269 | train rmse: 2.5214
# Iteration 100 | train llk: -3198065 | train rmse: 2.5178
#
#
# Optimization finished
# Final log-likelihood: -3198065
# Final RMSE: 2.5178
# Minutes taken (optimization part): 1.9
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3691
# Latent factors to use: 60
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4855426 | train rmse: 2.9095
# Iteration 20 | train llk: -3954145 | train rmse: 2.7038
# Iteration 30 | train llk: -3624886 | train rmse: 2.6235
# Iteration 40 | train llk: -3475818 | train rmse: 2.5875
# Iteration 50 | train llk: -3389818 | train rmse: 2.5664
# Iteration 60 | train llk: -3333043 | train rmse: 2.5522
# Iteration 70 | train llk: -3291626 | train rmse: 2.5413
# Iteration 80 | train llk: -3258887 | train rmse: 2.5329
# Iteration 90 | train llk: -3235154 | train rmse: 2.5269
# Iteration 100 | train llk: -3217480 | train rmse: 2.5225
#
#
# Optimization finished
# Final log-likelihood: -3217480
# Final RMSE: 2.5225
# Minutes taken (optimization part): 1.9
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3703
# Latent factors to use: 60
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4816117 | train rmse: 2.9048
# Iteration 20 | train llk: -3950868 | train rmse: 2.7062
# Iteration 30 | train llk: -3622970 | train rmse: 2.6263
# Iteration 40 | train llk: -3454338 | train rmse: 2.5841
# Iteration 50 | train llk: -3361637 | train rmse: 2.5597
# Iteration 60 | train llk: -3304954 | train rmse: 2.5446
# Iteration 70 | train llk: -3267260 | train rmse: 2.5345
# Iteration 80 | train llk: -3241066 | train rmse: 2.5277
# Iteration 90 | train llk: -3219969 | train rmse: 2.5222
# Iteration 100 | train llk: -3204518 | train rmse: 2.5184
#
#
# Optimization finished
# Final log-likelihood: -3204518
# Final RMSE: 2.5184
# Minutes taken (optimization part): 1.9
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3699
# Latent factors to use: 60
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4842647 | train rmse: 2.9041
# Iteration 20 | train llk: -3926214 | train rmse: 2.6962
# Iteration 30 | train llk: -3601500 | train rmse: 2.6170
# Iteration 40 | train llk: -3441462 | train rmse: 2.5765
# Iteration 50 | train llk: -3354627 | train rmse: 2.5550
# Iteration 60 | train llk: -3301668 | train rmse: 2.5423
# Iteration 70 | train llk: -3268343 | train rmse: 2.5343
# Iteration 80 | train llk: -3242996 | train rmse: 2.5282
# Iteration 90 | train llk: -3222525 | train rmse: 2.5231
# Iteration 100 | train llk: -3204589 | train rmse: 2.5186
#
#
# Optimization finished
# Final log-likelihood: -3204589
# Final RMSE: 2.5186
# Minutes taken (optimization part): 1.9
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3702
# Latent factors to use: 60
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4840329 | train rmse: 2.9108
# Iteration 20 | train llk: -3989935 | train rmse: 2.7159
# Iteration 30 | train llk: -3644816 | train rmse: 2.6296
# Iteration 40 | train llk: -3472652 | train rmse: 2.5856
# Iteration 50 | train llk: -3377839 | train rmse: 2.5616
# Iteration 60 | train llk: -3320616 | train rmse: 2.5465
# Iteration 70 | train llk: -3283759 | train rmse: 2.5368
# Iteration 80 | train llk: -3257351 | train rmse: 2.5296
# Iteration 90 | train llk: -3238289 | train rmse: 2.5245
# Iteration 100 | train llk: -3223831 | train rmse: 2.5208
#
#
# Optimization finished
# Final log-likelihood: -3223831
# Final RMSE: 2.5208
# Minutes taken (optimization part): 1.9
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3704
# Latent factors to use: 97
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4691661 | train rmse: 2.8814
# Iteration 20 | train llk: -3788317 | train rmse: 2.6715
# Iteration 30 | train llk: -3455223 | train rmse: 2.5879
# Iteration 40 | train llk: -3292429 | train rmse: 2.5451
# Iteration 50 | train llk: -3201401 | train rmse: 2.5202
# Iteration 60 | train llk: -3145298 | train rmse: 2.5048
# Iteration 70 | train llk: -3108007 | train rmse: 2.4946
# Iteration 80 | train llk: -3081609 | train rmse: 2.4876
# Iteration 90 | train llk: -3061705 | train rmse: 2.4822
# Iteration 100 | train llk: -3046402 | train rmse: 2.4779
#
#
# Optimization finished
# Final log-likelihood: -3046402
# Final RMSE: 2.4779
# Minutes taken (optimization part): 3.0
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3700
# Latent factors to use: 97
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4674277 | train rmse: 2.8762
# Iteration 20 | train llk: -3782664 | train rmse: 2.6687
# Iteration 30 | train llk: -3448256 | train rmse: 2.5823
# Iteration 40 | train llk: -3290939 | train rmse: 2.5409
# Iteration 50 | train llk: -3204703 | train rmse: 2.5182
# Iteration 60 | train llk: -3151366 | train rmse: 2.5040
# Iteration 70 | train llk: -3113274 | train rmse: 2.4939
# Iteration 80 | train llk: -3084310 | train rmse: 2.4862
# Iteration 90 | train llk: -3062852 | train rmse: 2.4803
# Iteration 100 | train llk: -3046819 | train rmse: 2.4759
#
#
# Optimization finished
# Final log-likelihood: -3046819
# Final RMSE: 2.4759
# Minutes taken (optimization part): 3.0
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3700
# Latent factors to use: 97
# Initializing parameters...
# Allocating Phi matrix...
# ...
#
#
# Optimization finished
# Final log-likelihood: -3450076
# Final RMSE: 2.5830
# Minutes taken (optimization part): 1.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3702
# Latent factors to use: 34
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4941994 | train rmse: 2.9267
# Iteration 20 | train llk: -4092709 | train rmse: 2.7414
# Iteration 30 | train llk: -3786286 | train rmse: 2.6684
# Iteration 40 | train llk: -3640540 | train rmse: 2.6315
# Iteration 50 | train llk: -3564615 | train rmse: 2.6119
# Iteration 60 | train llk: -3519505 | train rmse: 2.6000
# Iteration 70 | train llk: -3490117 | train rmse: 2.5919
# Iteration 80 | train llk: -3470707 | train rmse: 2.5868
# Iteration 90 | train llk: -3456452 | train rmse: 2.5833
# Iteration 100 | train llk: -3445869 | train rmse: 2.5808
#
#
# Optimization finished
# Final log-likelihood: -3445869
# Final RMSE: 2.5808
# Minutes taken (optimization part): 1.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3705
# Latent factors to use: 87
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4729277 | train rmse: 2.8886
# Iteration 20 | train llk: -3828941 | train rmse: 2.6802
# Iteration 30 | train llk: -3487436 | train rmse: 2.5924
# Iteration 40 | train llk: -3338738 | train rmse: 2.5524
# Iteration 50 | train llk: -3256319 | train rmse: 2.5305
# Iteration 60 | train llk: -3203709 | train rmse: 2.5168
# Iteration 70 | train llk: -3167593 | train rmse: 2.5074
# Iteration 80 | train llk: -3141092 | train rmse: 2.5005
# Iteration 90 | train llk: -3121300 | train rmse: 2.4953
# Iteration 100 | train llk: -3105738 | train rmse: 2.4912
#
#
# Optimization finished
# Final log-likelihood: -3105738
# Final RMSE: 2.4912
# Minutes taken (optimization part): 2.7
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3699
# Latent factors to use: 87
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4729542 | train rmse: 2.8861
# Iteration 20 | train llk: -3814793 | train rmse: 2.6759
# Iteration 30 | train llk: -3483628 | train rmse: 2.5941
# Iteration 40 | train llk: -3321168 | train rmse: 2.5532
# Iteration 50 | train llk: -3233335 | train rmse: 2.5306
# Iteration 60 | train llk: -3176335 | train rmse: 2.5159
# Iteration 70 | train llk: -3136288 | train rmse: 2.5056
# Iteration 80 | train llk: -3108638 | train rmse: 2.4984
# Iteration 90 | train llk: -3088659 | train rmse: 2.4931
# Iteration 100 | train llk: -3073464 | train rmse: 2.4889
#
#
# Optimization finished
# Final log-likelihood: -3073464
# Final RMSE: 2.4889
# Minutes taken (optimization part): 2.7
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 6040
# Number of items: 3705
# Latent factors to use: 87
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -4729473 | train rmse: 2.8845
# Iteration 20 | train llk: -3840913 | train rmse: 2.6783
# Iteration 30 | train llk: -3514223 | train rmse: 2.5982
# Iteration 40 | train llk: -3354657 | train rmse: 2.5566
# Iteration 50 | train llk: -3264276 | train rmse: 2.5320
# Iteration 60 | train llk: -3206512 | train rmse: 2.5163
# Iteration 70 | train llk: -3167861 | train rmse: 2.5060
# Iteration 80 | train llk: -3139201 | train rmse: 2.4981
#   7%|███                                         | 7/100 [1:13:01<13:48:36, 534.59s/it, best loss: -0.6181423222346267]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-3d88ad62cd50> in <module>
#       8 space={'features': hp.uniform('features', 1, 100)}
#       9
# ---> 10 best = fmin(objective, space, algo=tpe.suggest,max_evals=100)
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     405                     show_progressbar=show_progressbar)
#     406     rval.catch_eval_exceptions = catch_eval_exceptions
# --> 407     rval.exhaust()
#     408     if return_argmin:
#     409         return trials.argmin
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\fmin.py in exhaust(self)
#     260     def exhaust(self):
#     261         n_done = len(self.trials)
# --> 262         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     263         self.trials.refresh()
#     264         return self
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\fmin.py in run(self, N, block_until_done)
#     225                     else:
#     226                         # -- loop over trials and do the jobs directly
# --> 227                         self.serial_evaluate()
#     228
#     229                     try:
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\fmin.py in serial_evaluate(self, N)
#     139                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     140                 try:
# --> 141                     result = self.domain.evaluate(spec, ctrl)
#     142                 except Exception as e:
#     143                     logger.info('job exception: %s' % str(e))
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\base.py in evaluate(self, config, ctrl, attach_attachments)
#     842                 memo=memo,
#     843                 print_node_on_error=self.rec_eval_print_node_on_error)
# --> 844             rval = self.fn(pyll_rval)
#     845
#     846         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-5-3d88ad62cd50> in objective(params)
#       2 def objective(params):
#       3     features = params['features']
# ----> 4     metric = model_trainer(features)
#       5     array.append([features,metric])
#       6     return {'loss': -metric, 'status': STATUS_OK}
#
# <ipython-input-2-bde64c208a3f> in model_trainer(features)
#       8     for train, test in xf.partition_users(ratings[['user', 'item', 'rating']], 5, xf.SampleFrac(0.2)):
#       9         test_data.append(test) # save testing data
# ---> 10         all_recs.append(eval('HPF', hpf, train, test))
#      11     all_recs = pd.concat(all_recs, ignore_index=True)
#      12     test_data = pd.concat(test_data, ignore_index=True)
#
# <ipython-input-1-88001a6a8c46> in eval(aname, algo, train, test)
#      15     fittable = util.clone(algo) # Object cloning means to create an exact copy of the original object.
#      16     fittable = Recommender.adapt(fittable)
# ---> 17     fittable.fit(train) # Entrenamos el algoritmo con el training dataset
#      18     users = test.user.unique() # Devuelve un array con los users unicos en el testing dataset
#      19     # now we run the recommender
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\lenskit\algorithms\basic.py in fit(self, ratings, *args, **kwargs)
#     297                 Additional arguments for the predictor to use in its training process.
#     298         """
# --> 299         self.predictor.fit(ratings, *args, **kwargs)
#     300         self.selector.fit(ratings)
#     301         return self
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\lenskit\algorithms\hpf.py in fit(self, ratings)
#      44
#      45         _logger.info('fitting HPF model with %d features', self.features)
# ---> 46         hpf.fit(hpfdf)
#      47
#      48         self.user_index_ = users
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hpfrec\__init__.py in fit(self, counts_df, val_set)
#     399
#     400                 self._cast_before_fit()
# --> 401                 self._fit()
#     402
#     403                 ## after terminating optimization
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hpfrec\__init__.py in _fit(self)
#     634                         self.val_set.Count.values, self.val_set.UserId.values, self.val_set.ItemId.values,
#     635                         cython_loops.cast_int(self.full_llk), cython_loops.cast_int(self.keep_all_objs),
# --> 636                         cython_loops.cast_int(self.alloc_full_phi)
#     637 			)
#     638
#
# hpfrec\cython_loops.pyx in hpfrec.cython_loops.fit_hpf()
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      32     return umr_minimum(a, axis, None, out, keepdims, initial)
#      33
# ---> 34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      35          initial=_NoValue):
#      36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#
# KeyboardInterrupt:

# %%
array
# Out:
# [[65.59430402002553, 0.6141355882517721],
#  [34.12906552345305, 0.5942292687053243],
#  [60.349326395230484, 0.6067448858792008],
#  [97.56256911880097, 0.6181423222346267],
#  [26.572702588363036, 0.584850221834553],
#  [70.69014874935483, 0.6038840439879216],
#  [34.76581675485538, 0.587663886657299]]

# %%
array #484.24
# Out:
# [[97.20502597497644, 0.6076432874526915],
#  [49.77491683745057, 0.6003317370956137],
#  [14.017308798095296, 0.5560618417634258],
#  [79.93117694500465, 0.6135774174143143],
#  [98.22129176475292, 0.6141999733393998],
#  [18.112306335835463, 0.571593586672919],
#  [73.16369359072172, 0.6117045031040764],
#  [8.241546552145927, 0.5260145461351127],
#  [46.54122914922052, 0.5966631298786769]]

# %%
array #732.87
# Out:
# [[39.73032878212709, 0.6021935414690187],
#  [10.595937520042163, 0.5367866752050835],
#  [51.529047710234636, 0.6035835489022048],
#  [51.0795273032218, 0.6087265520905637],
#  [86.85512109914396, 0.6090624351727835],
#  [68.94130191450179, 0.6101551767152814],
#  [32.75762943024612, 0.5886479338339674],
#  [79.80995639325258, 0.6107819498076983],
#  [83.7469480939087, 0.6061108201435873],
#  [10.767963120053022, 0.5315013508031983],
#  [89.53585490883046, 0.617020804030599],
#  [68.95447191390741, 0.6085291052209971],
#  [8.667761651351372, 0.5258547916199315],
#  [20.73425821005075, 0.5671540367513078],
#  [24.95038680981864, 0.585025787249171],
#  [70.88110782446222, 0.6136522610412471],
#  [34.95412897557501, 0.593535977839417],
#  [71.87090221532823, 0.6113372450369973],
#  [69.17335520849385, 0.6145904240960516],
#  [79.92649097734815, 0.6097608032788292],
#  [95.7012762576808, 0.6145235290775581],
#  [98.60446576842725, 0.6088260679782895],
#  [60.54773742163389, 0.6043799913306916],
#  [91.61201745745771, 0.6125958100209551],
#  [61.069718619876504, 0.6096120771333479]]

# %%
array
# Out:
# [[60.396309920250815, 0.5995405053376486],
#  [75.48112924297375, 0.6076750681683537],
#  [59.27393710759018, 0.6079650121702811],
#  [94.14622055570538, 0.6141745984613832]]

# %%
array # 709.57
# Out:
# [[36.94319475826971, 0.5987794985039477],
#  [46.14999876351392, 0.6001882477988422],
#  [48.46864754388819, 0.5981813506557064],
#  [44.574558238933854, 0.6070014470159139],
#  [38.41508257295905, 0.5945904953860542],
#  [8.237793742837738, 0.5350987601233624],
#  [40.569165544511044, 0.5994683680301085],
#  [48.75495737438963, 0.6057830337276054],
#  [62.38863362448205, 0.6099397091813512],
#  [62.52527578731046, 0.6140067161580154],
#  [96.3684354170361, 0.6090328668215866],
#  [11.533082494757622, 0.5457012319478701],
#  [5.876306996549661, 0.5090757726601141],
#  [15.961458942653149, 0.5594327208331493],
#  [43.968990842777174, 0.605954517559999],
#  [31.454806772387524, 0.5867474442701333],
#  [61.48973920775618, 0.6109186368022065],
#  [81.04497180613224, 0.6174102776610534],
#  [34.918812944575365, 0.5966486631736432],
#  [99.59262139495203, 0.6142646106907486],
#  [99.44744717286511, 0.6091142506073596],
#  [83.36334802448715, 0.6126112527420333],
#  [85.46183609001923, 0.6200680921383169],
#  [82.7707949017874, 0.6096782353071498],
#  [83.93690859425682, 0.6147986539716936],
#  [75.99288686911567, 0.6158884287442824],
#  [70.65090310554237, 0.6198405084276105],
#  [71.0852487194779, 0.6202637070178311],
#  [92.65609612347822, 0.6078379348839654],
#  [90.20453829579586, 0.6112942438694994],
#  [56.96511646268218, 0.6099533613659851],
#  [69.81558610378244, 0.6156886826052338],
#  [55.047565575249436, 0.608873949489404],
#  [71.11093674355824, 0.6133733204523774],
#  [29.051651588467166, 0.5942962639369752],
#  [90.56673636874481, 0.6033450604295965],
#  [68.12124101598111, 0.6109257780126568],
#  [75.00752191574774, 0.6146476203276319],
#  [54.917428966155896, 0.6087724949404766],
#  [76.22999684774362, 0.6162989225700444],
#  [87.27954467339495, 0.6267724833309147],
#  [23.45328089796067, 0.5841440644369714],
#  [95.79854619258785, 0.61143285796236],
#  [65.74262131666359, 0.6132793207364869],
#  [51.28579820908615, 0.597262480340034],
#  [78.20256351173192, 0.6171538131959077]]

# %%
array #1389.55
# Out:
# [[60.927397396417106, 0.6066224893392048],
#  [31.30485481450014, 0.5976313423438571],
#  [93.53664162959849, 0.6114894445889173],
#  [31.280617114272843, 0.5890119074233477],
#  [86.37863130038224, 0.6132691342646599],
#  [50.365420190950296, 0.604650528010384],
#  [18.780911912845525, 0.5646430704718374],
#  [57.41887407949496, 0.6069432237929341],
#  [71.31712654214405, 0.6152305380176268],
#  [43.68365842446312, 0.6021641154164694],
#  [83.97796546759054, 0.6125875589763022],
#  [42.13227743112521, 0.6024282517747098]]

# %%
array #940
# Out:
# [[7.020515337595652, 0.5147708462632566],
#  [46.36974821499358, 0.6044926386445703],
#  [5.260399882376543, 0.49471010843303015],
#  [89.28853791025723, 0.6186136325846924]]

# %%
metric = pd.DataFrame(array)
metric.columns = ['features','MRR']
metric.head()
# Out:
#     features       MRR
# 0   7.020515  0.514771
# 1  46.369748  0.604493
# 2   5.260400  0.494710
# 3  89.288538  0.618614
# 4  60.927397  0.606622

# %%
metric.sort_values(by=['MRR'],ascending=False).head(10)
# Out:
#      features       MRR
# 56  87.279545  0.626772
# 43  71.085249  0.620264
# 38  85.461836  0.620068
# 42  70.650903  0.619841
# 3   89.288538  0.618614
# 33  81.044972  0.617410
# 61  78.202564  0.617154
# 76  89.535855  0.617021
# 55  76.229997  0.616299
# 41  75.992887  0.615888

# %%
metric.to_csv('metric_MRR.csv', index=False)

# %%
array = [[7.020515337595652, 0.5147708462632566],
 [46.36974821499358, 0.6044926386445703],
 [5.260399882376543, 0.49471010843303015],
 [89.28853791025723, 0.6186136325846924],
 [60.927397396417106, 0.6066224893392048],
 [31.30485481450014, 0.5976313423438571],
 [93.53664162959849, 0.6114894445889173],
 [31.280617114272843, 0.5890119074233477],
 [86.37863130038224, 0.6132691342646599],
 [50.365420190950296, 0.604650528010384],
 [18.780911912845525, 0.5646430704718374],
 [57.41887407949496, 0.6069432237929341],
 [71.31712654214405, 0.6152305380176268],
 [43.68365842446312, 0.6021641154164694],
 [83.97796546759054, 0.6125875589763022],
 [42.13227743112521, 0.6024282517747098],
 [36.94319475826971, 0.5987794985039477],
 [46.14999876351392, 0.6001882477988422],
 [48.46864754388819, 0.5981813506557064],
 [44.574558238933854, 0.6070014470159139],
 [38.41508257295905, 0.5945904953860542],
 [8.237793742837738, 0.5350987601233624],
 [40.569165544511044, 0.5994683680301085],
 [48.75495737438963, 0.6057830337276054],
 [62.38863362448205, 0.6099397091813512],
 [62.52527578731046, 0.6140067161580154],
 [96.3684354170361, 0.6090328668215866],
 [11.533082494757622, 0.5457012319478701],
 [5.876306996549661, 0.5090757726601141],
 [15.961458942653149, 0.5594327208331493],
 [43.968990842777174, 0.605954517559999],
 [31.454806772387524, 0.5867474442701333],
 [61.48973920775618, 0.6109186368022065],
 [81.04497180613224, 0.6174102776610534],
 [34.918812944575365, 0.5966486631736432],
 [99.59262139495203, 0.6142646106907486],
 [99.44744717286511, 0.6091142506073596],
 [83.36334802448715, 0.6126112527420333],
 [85.46183609001923, 0.6200680921383169],
 [82.7707949017874, 0.6096782353071498],
 [83.93690859425682, 0.6147986539716936],
 [75.99288686911567, 0.6158884287442824],
 [70.65090310554237, 0.6198405084276105],
 [71.0852487194779, 0.6202637070178311],
 [92.65609612347822, 0.6078379348839654],
 [90.20453829579586, 0.6112942438694994],
 [56.96511646268218, 0.6099533613659851],
 [69.81558610378244, 0.6156886826052338],
 [55.047565575249436, 0.608873949489404],
 [71.11093674355824, 0.6133733204523774],
 [29.051651588467166, 0.5942962639369752],
 [90.56673636874481, 0.6033450604295965],
 [68.12124101598111, 0.6109257780126568],
 [75.00752191574774, 0.6146476203276319],
 [54.917428966155896, 0.6087724949404766],
 [76.22999684774362, 0.6162989225700444],
 [87.27954467339495, 0.6267724833309147],
 [23.45328089796067, 0.5841440644369714],
 [95.79854619258785, 0.61143285796236],
 [65.74262131666359, 0.6132793207364869],
 [51.28579820908615, 0.597262480340034],
 [78.20256351173192, 0.6171538131959077],
 [60.396309920250815, 0.5995405053376486],
 [75.48112924297375, 0.6076750681683537],
 [59.27393710759018, 0.6079650121702811],
 [94.14622055570538, 0.6141745984613832],
 [39.73032878212709, 0.6021935414690187],
 [10.595937520042163, 0.5367866752050835],
 [51.529047710234636, 0.6035835489022048],
 [51.0795273032218, 0.6087265520905637],
 [86.85512109914396, 0.6090624351727835],
 [68.94130191450179, 0.6101551767152814],
 [32.75762943024612, 0.5886479338339674],
 [79.80995639325258, 0.6107819498076983],
 [83.7469480939087, 0.6061108201435873],
 [10.767963120053022, 0.5315013508031983],
 [89.53585490883046, 0.617020804030599],
 [68.95447191390741, 0.6085291052209971],
 [8.667761651351372, 0.5258547916199315],
 [20.73425821005075, 0.5671540367513078],
 [24.95038680981864, 0.585025787249171],
 [70.88110782446222, 0.6136522610412471],
 [34.95412897557501, 0.593535977839417],
 [71.87090221532823, 0.6113372450369973],
 [69.17335520849385, 0.6145904240960516],
 [79.92649097734815, 0.6097608032788292],
 [95.7012762576808, 0.6145235290775581],
 [98.60446576842725, 0.6088260679782895],
 [60.54773742163389, 0.6043799913306916],
 [91.61201745745771, 0.6125958100209551],
 [61.069718619876504, 0.6096120771333479],
 [97.20502597497644, 0.6076432874526915],
 [49.77491683745057, 0.6003317370956137],
 [14.017308798095296, 0.5560618417634258],
 [79.93117694500465, 0.6135774174143143],
 [98.22129176475292, 0.6141999733393998],
 [18.112306335835463, 0.571593586672919],
 [73.16369359072172, 0.6117045031040764],
 [8.241546552145927, 0.5260145461351127],
 [46.54122914922052, 0.5966631298786769]]
