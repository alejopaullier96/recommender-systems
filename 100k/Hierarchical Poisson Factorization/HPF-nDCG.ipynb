# %% [markdown]
# <img src="https://www3.um.edu.uy/logoum.jpg" width=300>
# <h1 align="center">Thesis - HPF nDCG</h1>
# <h2 align="center">Alejo Paullier</h2>

# %% [markdown]
# https://lkpy.lenskit.org/en/stable/knn.html

# %%
from lenskit import batch, topn, util
from lenskit import crossfold as xf
from lenskit.algorithms import Recommender
from lenskit.algorithms.hpf import HPF as hpfl
from hpfrec import HPF
import pandas as pd
import numpy as np
from hyperopt import fmin, tpe, hp, STATUS_OK

ratings = pd.read_csv('C:\\Users\\Alejo\\Tesis\\Demo\\ml-100k\\u.data', sep='\t',
                      names=['user', 'item', 'rating', 'timestamp'])


def eval(aname, algo, train, test):
    fittable = util.clone(algo) # Object cloning means to create an exact copy of the original object.
    fittable = Recommender.adapt(fittable) 
    fittable.fit(train) # Entrenamos el algoritmo con el training dataset
    users = test.user.unique() # Devuelve un array con los users unicos en el testing dataset
    # now we run the recommender
    recs = batch.recommend(fittable, users, 100)
    # add the algorithm name for analyzability
    recs['Algorithm'] = aname
    return recs

# %%
def model_trainer(features):
    all_recs = []
    test_data = []
    features=int(features)
    
    hpf = hpfl(features,verbose=False) # define algorithm
    
    for train, test in xf.partition_users(ratings[['user', 'item', 'rating']], 5, xf.SampleFrac(0.2)):
        test_data.append(test) # save testing data
        all_recs.append(eval('HPF', hpf, train, test))
    all_recs = pd.concat(all_recs, ignore_index=True)
    test_data = pd.concat(test_data, ignore_index=True)
    rla = topn.RecListAnalysis()
    rla.add_metric(topn.ndcg)
    results = rla.compute(all_recs, test_data)
    return results["ndcg"].mean()

# %%
array = []
def objective(params):
    features = params['features']
    metric = model_trainer(features)
    array.append([features,metric])
    return {'loss': metric, 'status': STATUS_OK}

space={'features': hp.uniform('features', 1, 100)}

best = fmin(objective, space, algo=tpe.suggest,max_evals=100)
# Out:
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1670
# Latent factors to use: 66
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -344648 | train rmse: 2.6003
# Iteration 20 | train llk: -286985 | train rmse: 2.4490
# Iteration 30 | train llk: -269647 | train rmse: 2.3966
# Iteration 40 | train llk: -262126 | train rmse: 2.3731
# Iteration 50 | train llk: -257714 | train rmse: 2.3583
# Iteration 60 | train llk: -254673 | train rmse: 2.3482
# Iteration 70 | train llk: -252571 | train rmse: 2.3405
# Iteration 80 | train llk: -251021 | train rmse: 2.3351
# Iteration 90 | train llk: -249875 | train rmse: 2.3311
# Iteration 100 | train llk: -248964 | train rmse: 2.3281
#
#
# Optimization finished
# Final log-likelihood: -248964
# Final RMSE: 2.3281
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1675
# Latent factors to use: 66
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -347603 | train rmse: 2.6077
# Iteration 20 | train llk: -287758 | train rmse: 2.4514
# Iteration 30 | train llk: -269177 | train rmse: 2.3905
# Iteration 40 | train llk: -260593 | train rmse: 2.3611
# Iteration 50 | train llk: -255890 | train rmse: 2.3458
# Iteration 60 | train llk: -252759 | train rmse: 2.3349
# Iteration 70 | train llk: -250795 | train rmse: 2.3286
# Iteration 80 | train llk: -249247 | train rmse: 2.3233
# Iteration 90 | train llk: -248027 | train rmse: 2.3189
# Iteration 100 | train llk: -247049 | train rmse: 2.3158
#
#
# Optimization finished
# Final log-likelihood: -247049
# Final RMSE: 2.3158
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1675
# Latent factors to use: 66
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -343968 | train rmse: 2.6017
# Iteration 20 | train llk: -285757 | train rmse: 2.4536
# Iteration 30 | train llk: -267901 | train rmse: 2.3972
# Iteration 40 | train llk: -259387 | train rmse: 2.3660
# Iteration 50 | train llk: -254695 | train rmse: 2.3482
# Iteration 60 | train llk: -251761 | train rmse: 2.3378
# Iteration 70 | train llk: -249842 | train rmse: 2.3305
# Iteration 80 | train llk: -248392 | train rmse: 2.3250
# Iteration 90 | train llk: -247279 | train rmse: 2.3209
# Iteration 100 | train llk: -246447 | train rmse: 2.3179
#
#
# Optimization finished
# Final log-likelihood: -246447
# Final RMSE: 2.3179
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1678
# Latent factors to use: 66
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -347705 | train rmse: 2.5967
# Iteration 20 | train llk: -285654 | train rmse: 2.4365
# Iteration 30 | train llk: -268401 | train rmse: 2.3839
# Iteration 40 | train llk: -260428 | train rmse: 2.3584
# Iteration 50 | train llk: -255999 | train rmse: 2.3443
# Iteration 60 | train llk: -253020 | train rmse: 2.3345
# Iteration 70 | train llk: -250971 | train rmse: 2.3287
# Iteration 80 | train llk: -249426 | train rmse: 2.3243
# Iteration 90 | train llk: -248212 | train rmse: 2.3203
# Iteration 100 | train llk: -247211 | train rmse: 2.3170
#
#
# Optimization finished
# Final log-likelihood: -247211
# Final RMSE: 2.3170
# Minutes taken (optimization part): 0.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1682
# Latent factors to use: 66
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -339323 | train rmse: 2.5826
# Iteration 20 | train llk: -284479 | train rmse: 2.4277
# Iteration 30 | train llk: -267139 | train rmse: 2.3728
# Iteration 40 | train llk: -259136 | train rmse: 2.3474
# Iteration 50 | train llk: -254912 | train rmse: 2.3351
# Iteration 60 | train llk: -252155 | train rmse: 2.3273
# Iteration 70 | train llk: -250191 | train rmse: 2.3213
# Iteration 80 | train llk: -248631 | train rmse: 2.3166
# Iteration 90 | train llk: -247449 | train rmse: 2.3130
# Iteration 100 | train llk: -246595 | train rmse: 2.3099
#
#
# Optimization finished
# Final log-likelihood: -246595
# Final RMSE: 2.3099
# Minutes taken (optimization part): 0.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1674
# Latent factors to use: 30
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -367142 | train rmse: 2.6523
# Iteration 20 | train llk: -308602 | train rmse: 2.5051
# Iteration 30 | train llk: -290209 | train rmse: 2.4457
# Iteration 40 | train llk: -282184 | train rmse: 2.4192
# Iteration 50 | train llk: -277787 | train rmse: 2.4046
# Iteration 60 | train llk: -274686 | train rmse: 2.3941
# Iteration 70 | train llk: -272595 | train rmse: 2.3872
# Iteration 80 | train llk: -271063 | train rmse: 2.3831
# Iteration 90 | train llk: -269735 | train rmse: 2.3796
# Iteration 100 | train llk: -268801 | train rmse: 2.3768
#
#
# Optimization finished
# Final log-likelihood: -268801
# Final RMSE: 2.3768
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1677
# Latent factors to use: 30
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -372614 | train rmse: 2.6595
# Iteration 20 | train llk: -307878 | train rmse: 2.5012
# Iteration 30 | train llk: -289671 | train rmse: 2.4458
# Iteration 40 | train llk: -281721 | train rmse: 2.4208
# Iteration 50 | train llk: -277287 | train rmse: 2.4073
# Iteration 60 | train llk: -274502 | train rmse: 2.3987
# Iteration 70 | train llk: -272525 | train rmse: 2.3921
# Iteration 80 | train llk: -271116 | train rmse: 2.3874
# Iteration 90 | train llk: -270041 | train rmse: 2.3840
# Iteration 100 | train llk: -269217 | train rmse: 2.3812
#
#
# Optimization finished
# Final log-likelihood: -269217
# Final RMSE: 2.3812
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1679
# Latent factors to use: 30
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -371987 | train rmse: 2.6596
# Iteration 20 | train llk: -310092 | train rmse: 2.5089
# Iteration 30 | train llk: -290234 | train rmse: 2.4479
# Iteration 40 | train llk: -282038 | train rmse: 2.4224
# Iteration 50 | train llk: -277232 | train rmse: 2.4063
# Iteration 60 | train llk: -274525 | train rmse: 2.3972
# Iteration 70 | train llk: -272682 | train rmse: 2.3914
# Iteration 80 | train llk: -271221 | train rmse: 2.3868
# Iteration 90 | train llk: -270120 | train rmse: 2.3834
# Iteration 100 | train llk: -269274 | train rmse: 2.3805
#
#
# Optimization finished
# Final log-likelihood: -269274
# Final RMSE: 2.3805
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1667
# Latent factors to use: 30
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -371078 | train rmse: 2.6577
# Iteration 20 | train llk: -311854 | train rmse: 2.5128
# Iteration 30 | train llk: -293173 | train rmse: 2.4569
# Iteration 40 | train llk: -284804 | train rmse: 2.4312
# Iteration 50 | train llk: -279920 | train rmse: 2.4159
# Iteration 60 | train llk: -276742 | train rmse: 2.4060
# Iteration 70 | train llk: -274588 | train rmse: 2.3995
# Iteration 80 | train llk: -273149 | train rmse: 2.3951
# Iteration 90 | train llk: -272029 | train rmse: 2.3916
# Iteration 100 | train llk: -271251 | train rmse: 2.3893
#
#
# Optimization finished
# Final log-likelihood: -271251
# Final RMSE: 2.3893
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1680
# Latent factors to use: 30
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -384582 | train rmse: 2.6785
# Iteration 20 | train llk: -314802 | train rmse: 2.5140
# Iteration 30 | train llk: -294514 | train rmse: 2.4571
# Iteration 40 | train llk: -285348 | train rmse: 2.4285
# Iteration 50 | train llk: -280043 | train rmse: 2.4115
# Iteration 60 | train llk: -276663 | train rmse: 2.4011
# Iteration 70 | train llk: -274429 | train rmse: 2.3938
# Iteration 80 | train llk: -272776 | train rmse: 2.3881
# Iteration 90 | train llk: -271535 | train rmse: 2.3833
# Iteration 100 | train llk: -270649 | train rmse: 2.3803
#
#
# Optimization finished
# Final log-likelihood: -270649
# Final RMSE: 2.3803
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1677
# Latent factors to use: 87
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -344920 | train rmse: 2.5934
# Iteration 20 | train llk: -283627 | train rmse: 2.4307
# Iteration 30 | train llk: -264402 | train rmse: 2.3732
# Iteration 40 | train llk: -255455 | train rmse: 2.3452
# Iteration 50 | train llk: -250328 | train rmse: 2.3286
# Iteration 60 | train llk: -246769 | train rmse: 2.3175
# Iteration 70 | train llk: -244031 | train rmse: 2.3087
# Iteration 80 | train llk: -241869 | train rmse: 2.3007
# Iteration 90 | train llk: -240315 | train rmse: 2.2954
# Iteration 100 | train llk: -239094 | train rmse: 2.2915
#
#
# Optimization finished
# Final log-likelihood: -239094
# Final RMSE: 2.2915
# Minutes taken (optimization part): 0.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1678
# Latent factors to use: 87
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -333200 | train rmse: 2.5764
# Iteration 20 | train llk: -278232 | train rmse: 2.4228
# Iteration 30 | train llk: -261174 | train rmse: 2.3645
# Iteration 40 | train llk: -252708 | train rmse: 2.3368
# Iteration 50 | train llk: -247507 | train rmse: 2.3208
# Iteration 60 | train llk: -244341 | train rmse: 2.3114
# Iteration 70 | train llk: -242328 | train rmse: 2.3056
# Iteration 80 | train llk: -240773 | train rmse: 2.3010
# Iteration 90 | train llk: -239530 | train rmse: 2.2972
# Iteration 100 | train llk: -238543 | train rmse: 2.2941
#
#
# Optimization finished
# Final log-likelihood: -238543
# Final RMSE: 2.2941
# Minutes taken (optimization part): 0.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1679
# Latent factors to use: 87
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -338247 | train rmse: 2.5801
# Iteration 20 | train llk: -281208 | train rmse: 2.4231
# Iteration 30 | train llk: -263324 | train rmse: 2.3689
# Iteration 40 | train llk: -254923 | train rmse: 2.3424
# Iteration 50 | train llk: -250001 | train rmse: 2.3260
# Iteration 60 | train llk: -246730 | train rmse: 2.3148
# Iteration 70 | train llk: -244563 | train rmse: 2.3080
# Iteration 80 | train llk: -242948 | train rmse: 2.3031
# Iteration 90 | train llk: -241731 | train rmse: 2.2995
# Iteration 100 | train llk: -240765 | train rmse: 2.2969
#
#
# Optimization finished
# Final log-likelihood: -240765
# Final RMSE: 2.2969
# Minutes taken (optimization part): 0.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1674
# Latent factors to use: 87
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -336913 | train rmse: 2.5859
# Iteration 20 | train llk: -279409 | train rmse: 2.4315
# Iteration 30 | train llk: -261878 | train rmse: 2.3739
# Iteration 40 | train llk: -254174 | train rmse: 2.3464
# Iteration 50 | train llk: -250088 | train rmse: 2.3320
# Iteration 60 | train llk: -247468 | train rmse: 2.3231
# Iteration 70 | train llk: -245652 | train rmse: 2.3169
# Iteration 80 | train llk: -244224 | train rmse: 2.3125
# Iteration 90 | train llk: -243057 | train rmse: 2.3086
# Iteration 100 | train llk: -241974 | train rmse: 2.3053
#
#
# Optimization finished
# Final log-likelihood: -241974
# Final RMSE: 2.3053
# Minutes taken (optimization part): 0.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1676
# Latent factors to use: 87
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -339484 | train rmse: 2.5740
# Iteration 20 | train llk: -279251 | train rmse: 2.4138
# Iteration 30 | train llk: -261353 | train rmse: 2.3584
# Iteration 40 | train llk: -253198 | train rmse: 2.3314
# Iteration 50 | train llk: -248730 | train rmse: 2.3169
# Iteration 60 | train llk: -245789 | train rmse: 2.3077
# Iteration 70 | train llk: -243921 | train rmse: 2.3025
# Iteration 80 | train llk: -242626 | train rmse: 2.2988
# Iteration 90 | train llk: -241591 | train rmse: 2.2957
# Iteration 100 | train llk: -240843 | train rmse: 2.2934
#
#
# Optimization finished
# Final log-likelihood: -240843
# Final RMSE: 2.2934
# Minutes taken (optimization part): 0.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1672
# Latent factors to use: 58
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -347530 | train rmse: 2.6032
# Iteration 20 | train llk: -290304 | train rmse: 2.4522
# Iteration 30 | train llk: -271754 | train rmse: 2.3942
# Iteration 40 | train llk: -263726 | train rmse: 2.3668
# Iteration 50 | train llk: -258999 | train rmse: 2.3511
# Iteration 60 | train llk: -255971 | train rmse: 2.3415
# Iteration 70 | train llk: -253986 | train rmse: 2.3356
# Iteration 80 | train llk: -252466 | train rmse: 2.3311
# Iteration 90 | train llk: -251321 | train rmse: 2.3278
# Iteration 100 | train llk: -250420 | train rmse: 2.3252
#
#
# Optimization finished
# Final log-likelihood: -250420
# Final RMSE: 2.3252
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1677
# Latent factors to use: 58
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -348259 | train rmse: 2.6038
# Iteration 20 | train llk: -290574 | train rmse: 2.4534
# Iteration 30 | train llk: -273532 | train rmse: 2.3998
# Iteration 40 | train llk: -265040 | train rmse: 2.3721
# Iteration 50 | train llk: -260395 | train rmse: 2.3570
# Iteration 60 | train llk: -257163 | train rmse: 2.3468
# Iteration 70 | train llk: -254793 | train rmse: 2.3393
# Iteration 80 | train llk: -253012 | train rmse: 2.3333
# Iteration 90 | train llk: -251778 | train rmse: 2.3295
# Iteration 100 | train llk: -250716 | train rmse: 2.3272
#
#
# Optimization finished
# Final log-likelihood: -250716
# Final RMSE: 2.3272
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1682
# Latent factors to use: 58
# Initializing parameters...
# Allocating Phi matrix...
# ...
# Final RMSE: nan
# Minutes taken (optimization part): 0.0
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1680
# Latent factors to use: 3
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 20 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 30 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 40 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 50 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 60 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 70 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 80 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 90 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 100 | train llk: -9223372036854775808 | train rmse: nan
#
#
# Optimization finished
# Final log-likelihood: -9223372036854775808
# Final RMSE: nan
# Minutes taken (optimization part): 0.0
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1671
# Latent factors to use: 3
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 20 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 30 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 40 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 50 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 60 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 70 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 80 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 90 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 100 | train llk: -9223372036854775808 | train rmse: nan
#
#
# Optimization finished
# Final log-likelihood: -9223372036854775808
# Final RMSE: nan
# Minutes taken (optimization part): 0.0
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1674
# Latent factors to use: 3
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 20 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 30 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 40 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 50 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 60 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 70 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 80 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 90 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 100 | train llk: -9223372036854775808 | train rmse: nan
#
#
# Optimization finished
# Final log-likelihood: -9223372036854775808
# Final RMSE: nan
# Minutes taken (optimization part): 0.0
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1676
# Latent factors to use: 3
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 20 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 30 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 40 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 50 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 60 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 70 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 80 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 90 | train llk: -9223372036854775808 | train rmse: nan
# Iteration 100 | train llk: -9223372036854775808 | train rmse: nan
#
#
# Optimization finished
# Final log-likelihood: -9223372036854775808
# Final RMSE: nan
# Minutes taken (optimization part): 0.0
#  25%|████████████                                    | 25/100 [26:09<1:18:24, 62.72s/it, best loss: 0.4172741820656656]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ndcg'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-8599e9bb8b9b> in <module>
#       8 space={'features': hp.uniform('features', 1, 100)}
#       9
# ---> 10 best = fmin(objective, space, algo=tpe.suggest,max_evals=100)
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     405                     show_progressbar=show_progressbar)
#     406     rval.catch_eval_exceptions = catch_eval_exceptions
# --> 407     rval.exhaust()
#     408     if return_argmin:
#     409         return trials.argmin
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\fmin.py in exhaust(self)
#     260     def exhaust(self):
#     261         n_done = len(self.trials)
# --> 262         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     263         self.trials.refresh()
#     264         return self
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\fmin.py in run(self, N, block_until_done)
#     225                     else:
#     226                         # -- loop over trials and do the jobs directly
# --> 227                         self.serial_evaluate()
#     228
#     229                     try:
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\fmin.py in serial_evaluate(self, N)
#     139                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     140                 try:
# --> 141                     result = self.domain.evaluate(spec, ctrl)
#     142                 except Exception as e:
#     143                     logger.info('job exception: %s' % str(e))
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\base.py in evaluate(self, config, ctrl, attach_attachments)
#     842                 memo=memo,
#     843                 print_node_on_error=self.rec_eval_print_node_on_error)
# --> 844             rval = self.fn(pyll_rval)
#     845
#     846         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-8-8599e9bb8b9b> in objective(params)
#       2 def objective(params):
#       3     features = params['features']
# ----> 4     metric = model_trainer(features)
#       5     array.append([features,metric])
#       6     return {'loss': metric, 'status': STATUS_OK}
#
# <ipython-input-3-5ab0b6188deb> in model_trainer(features)
#      14     rla.add_metric(topn.ndcg)
#      15     results = rla.compute(all_recs, test_data)
# ---> 16     return results["ndcg"].mean()
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ndcg'

# %%
metric = pd.DataFrame(array)
metric.columns = ['features','nDCG']
metric.head()
# Out:
#     features      nDCG
# 0  66.173224  0.452242
# 1  30.718546  0.464517
# 2  87.752957  0.433668
# 3  58.094526  0.448368
# 4  59.990422  0.445445

# %%
metric.sort_values(by=['nDCG'],ascending=False).head(10)
# Out:
#       features      nDCG
# 1    30.718546  0.464517
# 72   33.364718  0.463312
# 80   36.807115  0.462238
# 22   21.323316  0.460957
# 71   37.836276  0.460744
# 105  16.486145  0.460523
# 40   16.486145  0.460523
# 63   27.131520  0.459977
# 57   35.916680  0.459577
# 13   41.729566  0.459220

# %%
metric.to_csv('metric_nDCG.csv', index=False)
