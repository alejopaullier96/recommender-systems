# %% [markdown]
# <img src="https://www3.um.edu.uy/logoum.jpg" width=300>
# <h1 align="center">Thesis - HPF F1 </h1>
# <h2 align="center">Alejo Paullier</h2>

# %%
from lenskit import batch, topn, util
from lenskit import crossfold as xf
from lenskit.algorithms import Recommender
from lenskit.algorithms.hpf import HPF as hpfl
from hpfrec import HPF
import pandas as pd
import numpy as np
from hyperopt import fmin, tpe, hp, STATUS_OK
np.seterr(divide='ignore', invalid='ignore')

ratings = pd.read_csv('C:\\Users\\Alejo\\Tesis\\Demo\\ml-100k\\u.data', sep='\t',
                      names=['user', 'item', 'rating', 'timestamp'])


def eval(aname, algo, train, test):
    fittable = util.clone(algo) # Object cloning means to create an exact copy of the original object.
    fittable = Recommender.adapt(fittable) 
    fittable.fit(train) # Entrenamos el algoritmo con el training dataset
    users = test.user.unique() # Devuelve un array con los users unicos en el testing dataset
    # now we run the recommender
    recs = batch.recommend(fittable, users, 100)
    # add the algorithm name for analyzability
    recs['Algorithm'] = aname
    return recs

# %%
def model_trainer(features):
    all_recs = []
    test_data = []
    features=int(features)
    
    hpf = hpfl(features,verbose=False) # define algorithm
     
    for train, test in xf.partition_users(ratings[['user', 'item', 'rating']], 5, xf.SampleFrac(0.2)):
        test_data.append(test) # save testing data
        all_recs.append(eval('HPF', hpf, train, test))
    
    all_recs = pd.concat(all_recs, ignore_index=True)
    test_data = pd.concat(test_data, ignore_index=True)
    rla1 = topn.RecListAnalysis()
    rla2 = topn.RecListAnalysis()
    rla1.add_metric(topn.precision)
    rla2.add_metric(topn.recall)
    prec = rla1.compute(all_recs, test_data)
    rec = rla2.compute(all_recs, test_data)
    F1 = ((prec['precision'].values*rec['recall'].values*2)/(prec['precision'].values+rec['recall'].values))
    F1 = np.nan_to_num(F1)
    return [F1.mean(),prec['precision'].mean(),rec['recall'].mean()]

# %%
array=[]
def objective(params):
    features = params['features']
    metric = model_trainer(features)
    array.append([features,metric[0],metric[1],metric[2]])
    return {'loss': -metric[0], 'status': STATUS_OK }

space={'features': hp.uniform('features', 1, 100)}

best = fmin(objective, space, algo=tpe.suggest,max_evals=100)
# Out:
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1678
# Latent factors to use: 23
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -384654 | train rmse: 2.6827
# Iteration 20 | train llk: -321052 | train rmse: 2.5390
# Iteration 30 | train llk: -301843 | train rmse: 2.4874
# Iteration 40 | train llk: -292532 | train rmse: 2.4572
# Iteration 50 | train llk: -287259 | train rmse: 2.4396
# Iteration 60 | train llk: -283898 | train rmse: 2.4284
# Iteration 70 | train llk: -281723 | train rmse: 2.4211
# Iteration 80 | train llk: -280156 | train rmse: 2.4157
# Iteration 90 | train llk: -278950 | train rmse: 2.4117
# Iteration 100 | train llk: -277998 | train rmse: 2.4086
#
#
# Optimization finished
# Final log-likelihood: -277998
# Final RMSE: 2.4086
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1674
# Latent factors to use: 23
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -386302 | train rmse: 2.6812
# Iteration 20 | train llk: -320336 | train rmse: 2.5272
# Iteration 30 | train llk: -300217 | train rmse: 2.4657
# Iteration 40 | train llk: -290619 | train rmse: 2.4343
# Iteration 50 | train llk: -285634 | train rmse: 2.4185
# Iteration 60 | train llk: -282616 | train rmse: 2.4096
# Iteration 70 | train llk: -280428 | train rmse: 2.4031
# Iteration 80 | train llk: -278702 | train rmse: 2.3978
# Iteration 90 | train llk: -277417 | train rmse: 2.3937
# Iteration 100 | train llk: -276577 | train rmse: 2.3916
#
#
# Optimization finished
# Final log-likelihood: -276577
# Final RMSE: 2.3916
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1678
# Latent factors to use: 23
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -386249 | train rmse: 2.6908
# Iteration 20 | train llk: -323099 | train rmse: 2.5441
# Iteration 30 | train llk: -303288 | train rmse: 2.4850
# Iteration 40 | train llk: -294116 | train rmse: 2.4549
# Iteration 50 | train llk: -288511 | train rmse: 2.4359
# Iteration 60 | train llk: -285063 | train rmse: 2.4246
# Iteration 70 | train llk: -282717 | train rmse: 2.4165
# Iteration 80 | train llk: -281100 | train rmse: 2.4109
# Iteration 90 | train llk: -279985 | train rmse: 2.4078
# Iteration 100 | train llk: -279135 | train rmse: 2.4052
#
#
# Optimization finished
# Final log-likelihood: -279135
# Final RMSE: 2.4052
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1680
# Latent factors to use: 23
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -392428 | train rmse: 2.6944
# Iteration 20 | train llk: -323654 | train rmse: 2.5325
# Iteration 30 | train llk: -303935 | train rmse: 2.4831
# Iteration 40 | train llk: -295311 | train rmse: 2.4589
# Iteration 50 | train llk: -290384 | train rmse: 2.4440
# Iteration 60 | train llk: -287441 | train rmse: 2.4347
# Iteration 70 | train llk: -285329 | train rmse: 2.4284
# Iteration 80 | train llk: -283794 | train rmse: 2.4233
# Iteration 90 | train llk: -282538 | train rmse: 2.4191
# Iteration 100 | train llk: -281746 | train rmse: 2.4168
#
#
# Optimization finished
# Final log-likelihood: -281746
# Final RMSE: 2.4168
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1672
# Latent factors to use: 23
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -380519 | train rmse: 2.6817
# Iteration 20 | train llk: -321022 | train rmse: 2.5411
# Iteration 30 | train llk: -302556 | train rmse: 2.4866
# Iteration 40 | train llk: -293768 | train rmse: 2.4598
# Iteration 50 | train llk: -288634 | train rmse: 2.4445
# Iteration 60 | train llk: -285459 | train rmse: 2.4360
# Iteration 70 | train llk: -283402 | train rmse: 2.4307
# Iteration 80 | train llk: -281930 | train rmse: 2.4265
# Iteration 90 | train llk: -280793 | train rmse: 2.4230
# Iteration 100 | train llk: -279920 | train rmse: 2.4204
#
#
# Optimization finished
# Final log-likelihood: -279920
# Final RMSE: 2.4204
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1680
# Latent factors to use: 34
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -373682 | train rmse: 2.6600
# Iteration 20 | train llk: -308475 | train rmse: 2.5036
# Iteration 30 | train llk: -287494 | train rmse: 2.4420
# Iteration 40 | train llk: -278183 | train rmse: 2.4127
# Iteration 50 | train llk: -273110 | train rmse: 2.3966
# Iteration 60 | train llk: -270014 | train rmse: 2.3866
# Iteration 70 | train llk: -268000 | train rmse: 2.3797
# Iteration 80 | train llk: -266545 | train rmse: 2.3747
# Iteration 90 | train llk: -265475 | train rmse: 2.3713
# Iteration 100 | train llk: -264660 | train rmse: 2.3694
#
#
# Optimization finished
# Final log-likelihood: -264660
# Final RMSE: 2.3694
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1677
# Latent factors to use: 34
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -373183 | train rmse: 2.6639
# Iteration 20 | train llk: -309502 | train rmse: 2.5073
# Iteration 30 | train llk: -291511 | train rmse: 2.4532
# Iteration 40 | train llk: -282652 | train rmse: 2.4243
# Iteration 50 | train llk: -277298 | train rmse: 2.4070
# Iteration 60 | train llk: -273862 | train rmse: 2.3965
# Iteration 70 | train llk: -271533 | train rmse: 2.3895
# Iteration 80 | train llk: -269703 | train rmse: 2.3837
# Iteration 90 | train llk: -268521 | train rmse: 2.3801
# Iteration 100 | train llk: -267554 | train rmse: 2.3771
#
#
# Optimization finished
# Final log-likelihood: -267554
# Final RMSE: 2.3771
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1670
# Latent factors to use: 34
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -368749 | train rmse: 2.6505
# Iteration 20 | train llk: -305407 | train rmse: 2.4904
# Iteration 30 | train llk: -285513 | train rmse: 2.4339
# Iteration 40 | train llk: -277089 | train rmse: 2.4098
# Iteration 50 | train llk: -272464 | train rmse: 2.3965
# Iteration 60 | train llk: -269567 | train rmse: 2.3877
# Iteration 70 | train llk: -267569 | train rmse: 2.3816
# Iteration 80 | train llk: -266129 | train rmse: 2.3773
# Iteration 90 | train llk: -265085 | train rmse: 2.3745
# Iteration 100 | train llk: -264348 | train rmse: 2.3721
#
#
# Optimization finished
# Final log-likelihood: -264348
# Final RMSE: 2.3721
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1678
# Latent factors to use: 34
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -368593 | train rmse: 2.6478
# Iteration 20 | train llk: -307163 | train rmse: 2.5030
# Iteration 30 | train llk: -288880 | train rmse: 2.4477
# Iteration 40 | train llk: -280146 | train rmse: 2.4199
# Iteration 50 | train llk: -274888 | train rmse: 2.4025
# Iteration 60 | train llk: -271553 | train rmse: 2.3910
# Iteration 70 | train llk: -269431 | train rmse: 2.3832
# Iteration 80 | train llk: -267902 | train rmse: 2.3779
# Iteration 90 | train llk: -266672 | train rmse: 2.3737
# Iteration 100 | train llk: -265649 | train rmse: 2.3700
#
#
# Optimization finished
# Final log-likelihood: -265649
# Final RMSE: 2.3700
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1676
# Latent factors to use: 34
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -370050 | train rmse: 2.6671
# Iteration 20 | train llk: -306787 | train rmse: 2.5096
# Iteration 30 | train llk: -288249 | train rmse: 2.4528
# Iteration 40 | train llk: -280154 | train rmse: 2.4269
# Iteration 50 | train llk: -275537 | train rmse: 2.4118
# Iteration 60 | train llk: -272773 | train rmse: 2.4020
# Iteration 70 | train llk: -270984 | train rmse: 2.3958
# Iteration 80 | train llk: -269475 | train rmse: 2.3906
# Iteration 90 | train llk: -268534 | train rmse: 2.3872
# Iteration 100 | train llk: -267906 | train rmse: 2.3849
#
#
# Optimization finished
# Final log-likelihood: -267906
# Final RMSE: 2.3849
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1681
# Latent factors to use: 57
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -356148 | train rmse: 2.6242
# Iteration 20 | train llk: -292998 | train rmse: 2.4652
# Iteration 30 | train llk: -273820 | train rmse: 2.4067
# Iteration 40 | train llk: -265217 | train rmse: 2.3788
# Iteration 50 | train llk: -260451 | train rmse: 2.3629
# Iteration 60 | train llk: -257505 | train rmse: 2.3530
# Iteration 70 | train llk: -255634 | train rmse: 2.3470
# Iteration 80 | train llk: -254134 | train rmse: 2.3425
# Iteration 90 | train llk: -253030 | train rmse: 2.3388
# Iteration 100 | train llk: -252132 | train rmse: 2.3358
#
#
# Optimization finished
# Final log-likelihood: -252132
# Final RMSE: 2.3358
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1681
# Latent factors to use: 57
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -348108 | train rmse: 2.6117
# Iteration 20 | train llk: -288809 | train rmse: 2.4542
# Iteration 30 | train llk: -272082 | train rmse: 2.4004
# Iteration 40 | train llk: -264170 | train rmse: 2.3736
# Iteration 50 | train llk: -259197 | train rmse: 2.3567
# Iteration 60 | train llk: -255937 | train rmse: 2.3454
# Iteration 70 | train llk: -253863 | train rmse: 2.3387
# Iteration 80 | train llk: -252393 | train rmse: 2.3340
# Iteration 90 | train llk: -251397 | train rmse: 2.3306
# Iteration 100 | train llk: -250518 | train rmse: 2.3272
#
#
# Optimization finished
# Final log-likelihood: -250518
# Final RMSE: 2.3272
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1669
# Latent factors to use: 57
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -350517 | train rmse: 2.6072
# Iteration 20 | train llk: -288911 | train rmse: 2.4488
# Iteration 30 | train llk: -271489 | train rmse: 2.3959
# Iteration 40 | train llk: -263629 | train rmse: 2.3702
# Iteration 50 | train llk: -259107 | train rmse: 2.3552
# Iteration 60 | train llk: -256154 | train rmse: 2.3459
# Iteration 70 | train llk: -254070 | train rmse: 2.3388
# Iteration 80 | train llk: -252511 | train rmse: 2.3337
# Iteration 90 | train llk: -251307 | train rmse: 2.3299
# Iteration 100 | train llk: -250304 | train rmse: 2.3267
#
#
# Optimization finished
# Final log-likelihood: -250304
# Final RMSE: 2.3267
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1677
# Latent factors to use: 57
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -351761 | train rmse: 2.6132
# Iteration 20 | train llk: -292339 | train rmse: 2.4579
# Iteration 30 | train llk: -273554 | train rmse: 2.3990
# Iteration 40 | train llk: -264757 | train rmse: 2.3706
# Iteration 50 | train llk: -260015 | train rmse: 2.3552
# Iteration 60 | train llk: -257008 | train rmse: 2.3458
# Iteration 70 | train llk: -254787 | train rmse: 2.3387
# Iteration 80 | train llk: -253191 | train rmse: 2.3335
# Iteration 90 | train llk: -252009 | train rmse: 2.3298
# Iteration 100 | train llk: -251078 | train rmse: 2.3267
#
#
# Optimization finished
# Final log-likelihood: -251078
# Final RMSE: 2.3267
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1678
# Latent factors to use: 57
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -348530 | train rmse: 2.6089
# Iteration 20 | train llk: -293226 | train rmse: 2.4576
# Iteration 30 | train llk: -275038 | train rmse: 2.4017
# Iteration 40 | train llk: -265938 | train rmse: 2.3741
# Iteration 50 | train llk: -260922 | train rmse: 2.3596
# Iteration 60 | train llk: -257896 | train rmse: 2.3510
# Iteration 70 | train llk: -255610 | train rmse: 2.3447
# Iteration 80 | train llk: -253960 | train rmse: 2.3403
# Iteration 90 | train llk: -252824 | train rmse: 2.3371
# Iteration 100 | train llk: -251941 | train rmse: 2.3346
#
#
# Optimization finished
# Final log-likelihood: -251941
# Final RMSE: 2.3346
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1681
# Latent factors to use: 39
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -368718 | train rmse: 2.6485
# Iteration 20 | train llk: -305332 | train rmse: 2.4927
# Iteration 30 | train llk: -285144 | train rmse: 2.4332
# Iteration 40 | train llk: -275760 | train rmse: 2.4029
# Iteration 50 | train llk: -270766 | train rmse: 2.3875
# Iteration 60 | train llk: -267541 | train rmse: 2.3765
# Iteration 70 | train llk: -265606 | train rmse: 2.3706
# Iteration 80 | train llk: -264140 | train rmse: 2.3662
# Iteration 90 | train llk: -262984 | train rmse: 2.3628
# Iteration 100 | train llk: -262047 | train rmse: 2.3600
#
#
# Optimization finished
# Final log-likelihood: -262047
# Final RMSE: 2.3600
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1674
# Latent factors to use: 39
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -366566 | train rmse: 2.6437
# Iteration 20 | train llk: -301832 | train rmse: 2.4837
# Iteration 30 | train llk: -283020 | train rmse: 2.4268
# Iteration 40 | train llk: -274066 | train rmse: 2.3983
# Iteration 50 | train llk: -268947 | train rmse: 2.3823
# Iteration 60 | train llk: -265797 | train rmse: 2.3729
# Iteration 70 | train llk: -263497 | train rmse: 2.3665
# Iteration 80 | train llk: -261721 | train rmse: 2.3613
# Iteration 90 | train llk: -260386 | train rmse: 2.3568
# Iteration 100 | train llk: -259327 | train rmse: 2.3534
#
#
# Optimization finished
# Final log-likelihood: -259327
# Final RMSE: 2.3534
# Minutes taken (optimization part): 0.1
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1678
# Latent factors to use: 39
# Initializing parameters...
# Allocating Phi matrix...
# ...
# Iteration 100 | train llk: -247832 | train rmse: 2.3193
#
#
# Optimization finished
# Final log-likelihood: -247832
# Final RMSE: 2.3193
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1678
# Latent factors to use: 63
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -349573 | train rmse: 2.6167
# Iteration 20 | train llk: -294278 | train rmse: 2.4688
# Iteration 30 | train llk: -275105 | train rmse: 2.4071
# Iteration 40 | train llk: -265227 | train rmse: 2.3740
# Iteration 50 | train llk: -259497 | train rmse: 2.3554
# Iteration 60 | train llk: -256077 | train rmse: 2.3449
# Iteration 70 | train llk: -253604 | train rmse: 2.3375
# Iteration 80 | train llk: -251761 | train rmse: 2.3321
# Iteration 90 | train llk: -250428 | train rmse: 2.3287
# Iteration 100 | train llk: -249221 | train rmse: 2.3254
#
#
# Optimization finished
# Final log-likelihood: -249221
# Final RMSE: 2.3254
# Minutes taken (optimization part): 0.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1675
# Latent factors to use: 63
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -348846 | train rmse: 2.6130
# Iteration 20 | train llk: -289835 | train rmse: 2.4539
# Iteration 30 | train llk: -271316 | train rmse: 2.3940
# Iteration 40 | train llk: -262826 | train rmse: 2.3662
# Iteration 50 | train llk: -258177 | train rmse: 2.3520
# Iteration 60 | train llk: -255240 | train rmse: 2.3425
# Iteration 70 | train llk: -253111 | train rmse: 2.3355
# Iteration 80 | train llk: -251728 | train rmse: 2.3313
# Iteration 90 | train llk: -250698 | train rmse: 2.3281
# Iteration 100 | train llk: -249894 | train rmse: 2.3258
#
#
# Optimization finished
# Final log-likelihood: -249894
# Final RMSE: 2.3258
# Minutes taken (optimization part): 0.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1677
# Latent factors to use: 63
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -347463 | train rmse: 2.6003
# Iteration 20 | train llk: -286515 | train rmse: 2.4386
# Iteration 30 | train llk: -268325 | train rmse: 2.3828
# Iteration 40 | train llk: -260124 | train rmse: 2.3569
# Iteration 50 | train llk: -255817 | train rmse: 2.3437
# Iteration 60 | train llk: -252958 | train rmse: 2.3347
# Iteration 70 | train llk: -250923 | train rmse: 2.3288
# Iteration 80 | train llk: -249681 | train rmse: 2.3255
# Iteration 90 | train llk: -248739 | train rmse: 2.3230
# Iteration 100 | train llk: -248034 | train rmse: 2.3209
#
#
# Optimization finished
# Final log-likelihood: -248034
# Final RMSE: 2.3209
# Minutes taken (optimization part): 0.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1681
# Latent factors to use: 29
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -378216 | train rmse: 2.6712
# Iteration 20 | train llk: -311106 | train rmse: 2.5078
# Iteration 30 | train llk: -291868 | train rmse: 2.4433
# Iteration 40 | train llk: -282956 | train rmse: 2.4144
# Iteration 50 | train llk: -278092 | train rmse: 2.3997
# Iteration 60 | train llk: -275185 | train rmse: 2.3908
# Iteration 70 | train llk: -273340 | train rmse: 2.3854
#  11%|█████▏                                         | 11/100 [11:23<1:50:50, 74.72s/it, best loss: -0.1895987164174933]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-4ffdd66cc8f1> in <module>
#       8 space={'features': hp.uniform('features', 1, 100)}
#       9
# ---> 10 best = fmin(objective, space, algo=tpe.suggest,max_evals=100)
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar)
#     405                     show_progressbar=show_progressbar)
#     406     rval.catch_eval_exceptions = catch_eval_exceptions
# --> 407     rval.exhaust()
#     408     if return_argmin:
#     409         return trials.argmin
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\fmin.py in exhaust(self)
#     260     def exhaust(self):
#     261         n_done = len(self.trials)
# --> 262         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     263         self.trials.refresh()
#     264         return self
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\fmin.py in run(self, N, block_until_done)
#     225                     else:
#     226                         # -- loop over trials and do the jobs directly
# --> 227                         self.serial_evaluate()
#     228
#     229                     try:
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\fmin.py in serial_evaluate(self, N)
#     139                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     140                 try:
# --> 141                     result = self.domain.evaluate(spec, ctrl)
#     142                 except Exception as e:
#     143                     logger.info('job exception: %s' % str(e))
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hyperopt\base.py in evaluate(self, config, ctrl, attach_attachments)
#     842                 memo=memo,
#     843                 print_node_on_error=self.rec_eval_print_node_on_error)
# --> 844             rval = self.fn(pyll_rval)
#     845
#     846         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-16-4ffdd66cc8f1> in objective(params)
#       2 def objective(params):
#       3     features = params['features']
# ----> 4     metric = model_trainer(features)
#       5     array.append([features,metric[0],metric[1],metric[2]])
#       6     return {'loss': -metric[0], 'status': STATUS_OK }
#
# <ipython-input-2-37ae05623cd0> in model_trainer(features)
#       8     for train, test in xf.partition_users(ratings[['user', 'item', 'rating']], 5, xf.SampleFrac(0.2)):
#       9         test_data.append(test) # save testing data
# ---> 10         all_recs.append(eval('HPF', hpf, train, test))
#      11
#      12     all_recs = pd.concat(all_recs, ignore_index=True)
#
# <ipython-input-1-3ec5a9600ec9> in eval(aname, algo, train, test)
#      16     fittable = util.clone(algo) # Object cloning means to create an exact copy of the original object.
#      17     fittable = Recommender.adapt(fittable)
# ---> 18     fittable.fit(train) # Entrenamos el algoritmo con el training dataset
#      19     users = test.user.unique() # Devuelve un array con los users unicos en el testing dataset
#      20     # now we run the recommender
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\lenskit\algorithms\basic.py in fit(self, ratings, *args, **kwargs)
#     297                 Additional arguments for the predictor to use in its training process.
#     298         """
# --> 299         self.predictor.fit(ratings, *args, **kwargs)
#     300         self.selector.fit(ratings)
#     301         return self
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\lenskit\algorithms\hpf.py in fit(self, ratings)
#      44
#      45         _logger.info('fitting HPF model with %d features', self.features)
# ---> 46         hpf.fit(hpfdf)
#      47
#      48         self.user_index_ = users
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hpfrec\__init__.py in fit(self, counts_df, val_set)
#     399
#     400                 self._cast_before_fit()
# --> 401                 self._fit()
#     402
#     403                 ## after terminating optimization
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\hpfrec\__init__.py in _fit(self)
#     634                         self.val_set.Count.values, self.val_set.UserId.values, self.val_set.ItemId.values,
#     635                         cython_loops.cast_int(self.full_llk), cython_loops.cast_int(self.keep_all_objs),
# --> 636                         cython_loops.cast_int(self.alloc_full_phi)
#     637 			)
#     638
#
# hpfrec\cython_loops.pyx in hpfrec.cython_loops.fit_hpf()
#
# D:\Programas\Anaconda\Anaconda\Lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      32     return umr_minimum(a, axis, None, out, keepdims, initial)
#      33
# ---> 34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      35          initial=_NoValue):
#      36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#
# KeyboardInterrupt:

# %%
metric = pd.DataFrame(arra)
metric.columns = ['features','F1','Precision','Recall']
metric.head(5)
# Out:
#     features        F1  Precision    Recall
# 0  23.795394  0.186553   0.123468  0.665813
# 1  34.664361  0.188691   0.124825  0.673078
# 2  57.863228  0.185726   0.123033  0.655910
# 3  39.976360  0.187443   0.123955  0.667214
# 4  73.046172  0.183328   0.121188  0.655603

# %%
metric.sort_values(by=['F1'],ascending=False).head(10)
# Out:
#      features        F1  Precision    Recall
# 96  19.754314  0.191152   0.126384  0.681571
# 50  29.104089  0.190707   0.126405  0.676537
# 36  19.933295  0.190302   0.126013  0.675663
# 86  22.512658  0.190247   0.125864  0.679971
# 97  23.423897  0.190082   0.125822  0.675455
# 99  27.441202  0.189753   0.125673  0.671325
# 5   13.253687  0.189599   0.125376  0.677748
# 61  31.811370  0.189425   0.125313  0.677147
# 21  29.553828  0.189418   0.125355  0.676238
# 12  20.004908  0.189364   0.125323  0.677102

# %%
metric.shape
# Out:
# (100, 4)

# %%
metric.to_csv('metric_F1.csv', index=False)
