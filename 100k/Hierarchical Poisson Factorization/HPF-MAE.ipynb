# %% [markdown]
# <img src="https://www3.um.edu.uy/logoum.jpg" width=300>
# <h1 align="center">Thesis - HPF MAE</h1>
# <h2 align="center">Alejo Paullier</h2>

# %% [markdown]
# https://lkpy.lenskit.org/en/stable/knn.html

# %%
from lenskit import batch, topn, util
from lenskit import crossfold as xf
from lenskit.algorithms import Recommender
from lenskit.algorithms.hpf import HPF as hpfl
from lenskit.metrics.predict import mae
import pandas as pd
import numpy as np
from hpfrec import HPF
from hyperopt import fmin, tpe, hp, STATUS_OK

ratings = pd.read_csv('C:\\Users\\Alejo\\Tesis\\Demo\\ml-100k\\u.data', sep='\t',
                      names=['user', 'item', 'rating', 'timestamp'])


def eval(aname, algo, train, test):
    fittable = util.clone(algo) # Object cloning means to create an exact copy of the original object.
    fittable = Recommender.adapt(fittable) 
    fittable.fit(train) # train the algorithm with the training dataset
    # Now we run the recommender:
    preds = batch.predict(fittable, test)
    # add the algorithm name for analyzability
    return preds

# %%
def model_trainer(features):
    all_recs = []
    test_data = []
    features=int(features)
    
    hpf = hpfl(features,verbose=False) # define algorithm
    
    for train, test in xf.partition_users(ratings[['user', 'item', 'rating']], 5, xf.SampleFrac(0.2)):
        test_data.append(test) # save testing data
        all_recs.append(eval('HPF', hpf, train, test))
    
    all_recs = pd.concat(all_recs, ignore_index=True)

    metric = mae(all_recs['prediction'], all_recs['rating'])
    return metric

# %%
array = []

def objective(params):
    features = params['features']
    metric = model_trainer(features)
    array.append([features,metric])
    return {'loss': -metric, 'status': STATUS_OK}

space={'features': hp.uniform('features', 1, 100)}

best = fmin(objective, space, algo=tpe.suggest,max_evals=100)
# Out:
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1672
# Latent factors to use: 72
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -340737 | train rmse: 2.5905
# Iteration 20 | train llk: -285446 | train rmse: 2.4484
# Iteration 30 | train llk: -267568 | train rmse: 2.3918
# Iteration 40 | train llk: -258421 | train rmse: 2.3618
# Iteration 50 | train llk: -252946 | train rmse: 2.3435
# Iteration 60 | train llk: -249478 | train rmse: 2.3320
# Iteration 70 | train llk: -247156 | train rmse: 2.3247
# Iteration 80 | train llk: -245227 | train rmse: 2.3182
# Iteration 90 | train llk: -243827 | train rmse: 2.3135
# Iteration 100 | train llk: -242827 | train rmse: 2.3100
#
#
# Optimization finished
# Final log-likelihood: -242827
# Final RMSE: 2.3100
# Minutes taken (optimization part): 0.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1673
# Latent factors to use: 72
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -343746 | train rmse: 2.5987
# Iteration 20 | train llk: -288096 | train rmse: 2.4522
# Iteration 30 | train llk: -270299 | train rmse: 2.3969
# Iteration 40 | train llk: -261949 | train rmse: 2.3703
# Iteration 50 | train llk: -257075 | train rmse: 2.3556
# Iteration 60 | train llk: -254075 | train rmse: 2.3463
# Iteration 70 | train llk: -251752 | train rmse: 2.3383
# Iteration 80 | train llk: -250032 | train rmse: 2.3324
# Iteration 90 | train llk: -248596 | train rmse: 2.3275
# Iteration 100 | train llk: -247441 | train rmse: 2.3234
#
#
# Optimization finished
# Final log-likelihood: -247441
# Final RMSE: 2.3234
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1680
# Latent factors to use: 72
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -341678 | train rmse: 2.5915
# Iteration 20 | train llk: -285021 | train rmse: 2.4446
# Iteration 30 | train llk: -268346 | train rmse: 2.3901
# Iteration 40 | train llk: -260334 | train rmse: 2.3635
# Iteration 50 | train llk: -255576 | train rmse: 2.3482
# Iteration 60 | train llk: -252260 | train rmse: 2.3375
# Iteration 70 | train llk: -249864 | train rmse: 2.3301
# Iteration 80 | train llk: -248188 | train rmse: 2.3249
# Iteration 90 | train llk: -246846 | train rmse: 2.3203
# Iteration 100 | train llk: -245771 | train rmse: 2.3163
#
#
# Optimization finished
# Final log-likelihood: -245771
# Final RMSE: 2.3163
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1681
# Latent factors to use: 72
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -345144 | train rmse: 2.5974
# Iteration 20 | train llk: -285731 | train rmse: 2.4378
# Iteration 30 | train llk: -266596 | train rmse: 2.3780
# Iteration 40 | train llk: -257784 | train rmse: 2.3493
# Iteration 50 | train llk: -252983 | train rmse: 2.3335
# Iteration 60 | train llk: -249706 | train rmse: 2.3227
# Iteration 70 | train llk: -247346 | train rmse: 2.3149
# Iteration 80 | train llk: -245559 | train rmse: 2.3093
# Iteration 90 | train llk: -244295 | train rmse: 2.3057
# Iteration 100 | train llk: -243187 | train rmse: 2.3023
#
#
# Optimization finished
# Final log-likelihood: -243187
# Final RMSE: 2.3023
# Minutes taken (optimization part): 0.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1679
# Latent factors to use: 72
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -341944 | train rmse: 2.5861
# Iteration 20 | train llk: -284163 | train rmse: 2.4303
# Iteration 30 | train llk: -266729 | train rmse: 2.3758
# Iteration 40 | train llk: -258885 | train rmse: 2.3510
# Iteration 50 | train llk: -254500 | train rmse: 2.3377
# Iteration 60 | train llk: -251719 | train rmse: 2.3294
# Iteration 70 | train llk: -249765 | train rmse: 2.3238
# Iteration 80 | train llk: -248262 | train rmse: 2.3197
# Iteration 90 | train llk: -247113 | train rmse: 2.3165
# Iteration 100 | train llk: -246171 | train rmse: 2.3140
#
#
# Optimization finished
# Final log-likelihood: -246171
# Final RMSE: 2.3140
# Minutes taken (optimization part): 0.3
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1674
# Latent factors to use: 72
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -336223 | train rmse: 2.5778
# Iteration 20 | train llk: -281634 | train rmse: 2.4270
# Iteration 30 | train llk: -263878 | train rmse: 2.3726
# Iteration 40 | train llk: -255668 | train rmse: 2.3464
# Iteration 50 | train llk: -251307 | train rmse: 2.3328
# Iteration 60 | train llk: -248478 | train rmse: 2.3242
# Iteration 70 | train llk: -246473 | train rmse: 2.3180
# Iteration 80 | train llk: -245014 | train rmse: 2.3134
# Iteration 90 | train llk: -243853 | train rmse: 2.3100
# Iteration 100 | train llk: -243077 | train rmse: 2.3076
#
#
# Optimization finished
# Final log-likelihood: -243077
# Final RMSE: 2.3076
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1676
# Latent factors to use: 72
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -345024 | train rmse: 2.5977
# Iteration 20 | train llk: -285486 | train rmse: 2.4383
# Iteration 30 | train llk: -267828 | train rmse: 2.3851
# Iteration 40 | train llk: -260012 | train rmse: 2.3607
# Iteration 50 | train llk: -255459 | train rmse: 2.3461
# Iteration 60 | train llk: -252327 | train rmse: 2.3355
# Iteration 70 | train llk: -250353 | train rmse: 2.3290
# Iteration 80 | train llk: -248877 | train rmse: 2.3244
# Iteration 90 | train llk: -247681 | train rmse: 2.3210
# Iteration 100 | train llk: -246707 | train rmse: 2.3177
#
#
# Optimization finished
# Final log-likelihood: -246707
# Final RMSE: 2.3177
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1672
# Latent factors to use: 72
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -346081 | train rmse: 2.6047
# Iteration 20 | train llk: -287758 | train rmse: 2.4512
# Iteration 30 | train llk: -268903 | train rmse: 2.3936
# Iteration 40 | train llk: -260221 | train rmse: 2.3662
# Iteration 50 | train llk: -255122 | train rmse: 2.3493
# Iteration 60 | train llk: -251600 | train rmse: 2.3376
# Iteration 70 | train llk: -249205 | train rmse: 2.3292
# Iteration 80 | train llk: -247412 | train rmse: 2.3236
# Iteration 90 | train llk: -245880 | train rmse: 2.3188
# Iteration 100 | train llk: -244634 | train rmse: 2.3151
#
#
# Optimization finished
# Final log-likelihood: -244634
# Final RMSE: 2.3151
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1681
# Latent factors to use: 72
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -347661 | train rmse: 2.6066
# Iteration 20 | train llk: -286232 | train rmse: 2.4437
# Iteration 30 | train llk: -267942 | train rmse: 2.3850
# Iteration 40 | train llk: -259299 | train rmse: 2.3561
# Iteration 50 | train llk: -254485 | train rmse: 2.3402
# Iteration 60 | train llk: -251443 | train rmse: 2.3308
# Iteration 70 | train llk: -249277 | train rmse: 2.3239
# Iteration 80 | train llk: -247569 | train rmse: 2.3184
# Iteration 90 | train llk: -246325 | train rmse: 2.3143
# Iteration 100 | train llk: -245432 | train rmse: 2.3110
#
#
# Optimization finished
# Final log-likelihood: -245432
# Final RMSE: 2.3110
# Minutes taken (optimization part): 0.2
# **********************************
# Hierarchical Poisson Factorization
# **********************************
# Number of users: 943
# Number of items: 1678
# Latent factors to use: 72
# Initializing parameters...
# Allocating Phi matrix...
# Initializing optimization procedure...
# Iteration 10 | train llk: -351043 | train rmse: 2.6103
# Iteration 20 | train llk: -286841 | train rmse: 2.4413
# Iteration 30 | train llk: -266576 | train rmse: 2.3794
# Iteration 40 | train llk: -257497 | train rmse: 2.3503
# Iteration 50 | train llk: -252392 | train rmse: 2.3340
# Iteration 60 | train llk: -249192 | train rmse: 2.3248
# Iteration 70 | train llk: -246710 | train rmse: 2.3173
# Iteration 80 | train llk: -244884 | train rmse: 2.3116
# Iteration 90 | train llk: -243604 | train rmse: 2.3077
# Iteration 100 | train llk: -242480 | train rmse: 2.3045
#
#
# Optimization finished
# Final log-likelihood: -242480
# Final RMSE: 2.3045
# Minutes taken (optimization part): 0.2
# 100%|████████████████████████████████████████████████████| 2/2 [02:39<00:00, 82.15s/it, best loss: -2.7286487462023747]

# %%
metric = pd.DataFrame(array)
metric.columns = ['features','MAE']
metric.head(5)
# Out:
#     features       reg      RMSE
# 0  10.312233  0.052351  0.914337
# 1  10.449474  0.106525  0.911940
# 2  69.224375  0.184550  0.910361
# 3  82.333360  0.238358  0.913553
# 4  70.525621  0.258240  0.906652

# %%
metric.sort_values(by=['MAE'],ascending=True).head(10)
# Out:
#      features       reg      RMSE
# 47  67.969018  0.159718  0.900337
# 74  61.007370  0.156938  0.902556
# 70  82.091355  0.169876  0.902591
# 52  83.795977  0.045350  0.903057
# 37  88.372360  0.250508  0.903183
# 82  72.217708  0.124464  0.904008
# 93  70.098977  0.057532  0.904184
# 67  96.963554  0.285707  0.904514
# 40  87.925820  0.207074  0.904645
# 42  99.191023  0.213207  0.904821

# %%
metric.to_csv('metric_MAE.csv', index=False)
